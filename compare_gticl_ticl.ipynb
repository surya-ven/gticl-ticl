# %% [markdown]
# # Comparing GTICL and TICL Implementations
#
# This notebook provides a focused comparison of GTICL (GRPO Trial-Error-Explain In-Context Learning) and TICL (Trial-Error-Explain In-Context Learning) using:
#
# 1. The same dataset for training
# 2. The same tasks for inference
# 3. The same LLM provider

# %%
# Import necessary libraries
import os
import sys
import logging
import dotenv
import random
import time
from typing import List, Dict, Tuple

# Add parent directory to path to import modules
sys.path.append(os.path.abspath('.'))

# Import GTICL and TICL modules
from gticl.gticl_writing import GTICL, GTICLConfig
from gticl.llm_providers import OpenAIProvider
from gticl.dataset_utils import save_dataset
from ticl.ticl import TICL

# Load environment variables
dotenv.load_dotenv()

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("GTICL-TICL-Comparison")

# %% [markdown]
# ## Configure LLM Provider
#
# Set up a single LLM provider to be used by both GTICL and TICL.

# %%
# Configure OpenAI provider with OpenRouter
llm_provider = OpenAIProvider(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    model_id=os.getenv("LLM_MODEL_ID")
)

print(f"Using model: {os.getenv('LLM_MODEL_ID')} via OpenRouter")
# Out:
# Using model: google/gemini-2.0-flash-001 via OpenRouter

# %% [markdown]
# ## Create Dataset
#
# We'll create a consistent dataset of email examples to use for both GTICL and TICL.

# %%
# Create a dataset with casual email examples
casual_emails_dataset = [
    # Work-related emails
    {
        "task": "Write a casual email to Sam discussing yesterday's meeting where Alex proposed a risky new marketing push. Suggest meeting for coffee tomorrow after 2pm to discuss it further.",
        "reference_output": "Subject: thoughts on Friday's meeting?\n\nHey Sam,\n\nSooo... that meeting yesterday was interesting, huh? 😅 Not exactly what I expected!\n\nAnyway, I've been thinking about what Alex said about the new marketing push. Do you think we should go for it? Seems kinda risky to me, but then again, what do I know lol.\n\nWanna grab coffee tomorrow and chat about it? I'm free after 2.\n\nLater!\nJamie"
    },
    {
        "task": "Write an email to Taylor asking for feedback on a presentation you've been struggling with for 3 hours. Mention you need their help because they're better at this, and you'd appreciate feedback by Friday.",
        "reference_output": "Subject: can you help me with this?\n\nHey Taylor,\n\nI'm totally stuck on this presentation. Been staring at my screen for like 3 hours now! 🤦‍♀️\n\nYou're way better at this stuff than me... any chance you could take a quick look? Just need someone to tell me if it makes sense or if I sound like I'm rambling.\n\nNo rush - sometime before Friday would be amazing tho.\n\nThanks a million!\nAlex"
    },
    {
        "task": "Write an email apologizing for missing a scheduled call this morning because your alarm didn't go off (or you hit snooze too many times). Suggest rescheduling for tomorrow or Thursday after lunch.",
        "reference_output": "Subject: sry for missing the call\n\nHey,\n\nCrap, I totally missed our call this morning! My alarm didn't go off... or maybe I just hit snooze too many times? Either way, my bad.\n\nCan we reschedule? I'm free pretty much anytime tomorrow. Or Thursday after lunch maybe?\n\nLet me know what works for you.\n\nSorry again!\nRiley"
    },
    {
        "task": "Write an email to your team explaining that you'll miss the project deadline due to backend issues taking longer than expected. Suggest you need 1-2 more weeks and offer to discuss options on a call.",
        "reference_output": "Subject: sooo about that deadline...\n\nHey team,\n\nUgh, I hate to be the bearer of bad news, but we're gonna miss our target date. 😬 The backend issues are taking wayyy longer to fix than we thought.\n\nI'm thinking we need another week, maybe two? I know that's not what anyone wants to hear, but better to be realistic than promise something we can't deliver, right?\n\nLemme know your thoughts. We can hop on a quick call if you wanna discuss options.\n\nThanks for understanding (hopefully lol),\nJordan"
    },
    {
        "task": "Write an email to your boss requesting vacation days from May 15-19 because you're feeling burnt out. Assure them this is before the product launch and you'll have your work completed before leaving.",
        "reference_output": "Subject: vacation days next month??\n\nHey boss,\n\nSoooo I'm thinking about taking a little break before I completely lose my mind lol. 😅 Been feeling super burnt out lately.\n\nCould I take off May 15-19? That's the week before the big product launch, so everything should be pretty much wrapped up by then. I'll make sure all my stuff is done before I go, obvi.\n\nLet me know if that works or if you need me to shift the dates around!\n\nThanks a bunch,\nCasey"
    },
    {
        "task": "Write an email to the dev team about app issues you discovered during testing, where it crashes every 5 minutes on the checkout page. Mention you've tried troubleshooting with no success and need this fixed before tomorrow's launch.",
        "reference_output": "Subject: umm our app is kinda broken??\n\nHey dev team,\n\nSo I've been testing the app all morning and... yikes. 🙈 It's crashing like every 5 minutes on the checkout page.\n\nI tried all the usual stuff - cleared cache, restarted, even that weird thing with holding two buttons that Mark taught me lol. Nothing's working!\n\nCan someone take a look asap? Customers are gonna freeeeak if this goes live tomorrow.\n\nThanks for saving the day (again),\nJamie"
    },
    
    # Social/team emails
    {
        "task": "Write an email to your overworked team suggesting a happy hour this Thursday at the new place on 5th street that has deals until 7pm. Offer to buy the first round and make it clear there's no pressure to attend.",
        "reference_output": "Subject: drinks this week??\n\nHey everyone!\n\nSooo we've all been working crazy hours lately, and I think we deserve a break! 🍹\n\nAnyone up for happy hour this Thursday? That new place on 5th has amazing deals till 7pm. First round's on me (don't tell accounting lol).\n\nDrop a quick reply if you can make it. No pressure if you can't, but it'd be awesome to hang with you all outside this crazy office!\n\nCheers!\nCasey"
    },
    {
        "task": "Write an email to your team about Sarah's birthday next Friday. Suggest decorating her desk before she arrives (she's usually late), having lunch at her favorite Thai restaurant, and chipping in for a plant as a gift.",
        "reference_output": "Subject: sarah's bday surprise!!\n\nHeyyy team,\n\nSooo it's Sarah's birthday next Friday and we HAVE to do something fun! 🎂\n\nI'm thinking we could decorate her desk before she gets in (she always comes in late lol) and maybe grab lunch at that Thai place she loves?\n\nAnyone wanna chip in for a gift? I found this super cute plant for her desk - she's always talking about wanting more green stuff around.\n\nLet me know if you're in! And shhh... don't say anything to her!\n\nThx!\nTaylor"
    },
    {
        "task": "Write an email suggesting a zombie-themed escape room downtown for the next team-building activity, followed by dinner. Mention that everyone can bring a plus-one and you need responses by Tuesday to make the booking for next Friday after work.",
        "reference_output": "Subject: team bonding idea!!\n\nHey all,\n\nOk so I had this random thought last night... what if we did an escape room as our next team thing?? 🔎\n\nThere's this new place downtown that's supposed to be AMAZING. They have this zombie apocalypse theme that sounds super fun (and kinda terrifying tbh).\n\nWe could go next Friday after work and grab dinner after? Everyone can bring their plus-one if they want.\n\nWho's in?? Lemme know by Tuesday so I can book it!\n\nCan't wait!\nJordan"
    },
    
    # Personal/external emails
    {
        "task": "Write an excited email to a friend announcing your trip to their area from May 10-15. Ask to try the brunch place they posted about recently, and request to stay at their place for a few nights since hotels are expensive. Promise to bring their favorite cookies.",
        "reference_output": "Subject: my trip next month!!\n\nHeyyyy!\n\nOMG I just booked my flights for next month and I'm soooo excited! 🛫 Gonna be in your area May 10-15!\n\nPlease tell me you're free to hang?? I've been dying to try that brunch place you posted about last week - those pancakes looked INSANE.\n\nAlso, any chance I could crash at your place for a couple nights? Hotels are crazy expensive rn. Promise I'm still a good roomie lol. I'll bring those cookies you love!\n\nCan't wait to see youuuu!\nRiley"
    },
    {
        "task": "Write an email apologizing for completely forgetting your friend's birthday yesterday because your phone was dead all day. Offer to make it up with dinner at the new Italian restaurant next week.",
        "reference_output": "Subject: i'm the WORST friend ever 😭\n\nHey you,\n\nOmg I just realized I completely missed your birthday yesterday and I feel TERRIBLE!!! 😩 My phone was dead all day (classic me, right?) and I totally spaced.\n\nYou know I'd never forget on purpose, right? You're literally my favorite human!\n\nCan I make it up to you with dinner next week? That new Italian place just opened and I heard their pasta is to dieeee for.\n\nPretty please forgive me? 🙏\n\nLove youuuu!\nTaylor"
    },
    {
        "task": "Write a polite complaint email to a local store about finding bacon in your veggie sandwich that you purchased yesterday around 3pm. Mention you'd like to return despite this issue since people say their food is amazing.",
        "reference_output": "Subject: issue with my order yesterday\n\nHi there,\n\nSooo I was in your store yesterday around 3pm and had kind of a weird experience? 🙃\n\nI ordered the veggie sandwich but when I got home and unwrapped it... definitely not vegetarian! There was bacon all over it lol. I mean, bacon's great but not when you're not expecting it!\n\nNot sure if you guys were super busy or what, but thought you should know! I'd love to come back and try again since everyone says your food is amazing.\n\nThanks for listening to my little rant haha!\n\nAll the best,\nAlex"
    }
]

# Save dataset to a file
dataset_path = "dataset/comparison_dataset.json"
save_dataset(casual_emails_dataset, dataset_path)
print(f"Dataset with {len(casual_emails_dataset)} examples saved to {dataset_path}")
# Out:
# Dataset with 12 examples saved to dataset/comparison_dataset.json

# %% [markdown]
# ## Initialize GTICL and TICL
#
# Configure both frameworks with similar parameters for a fair comparison.

# %%
# Configure GTICL
gticl_config = GTICLConfig(
    k_candidates=3,       # Generate 3 candidates per input
    capacity=12,           # Store up to 5 negative samples per task
    iterations=2,         # Run 2 refinement iterations
    use_rewrite_update=True,  # Disable rewrite refinement for simplicity
    examples_per_prompt=2  # Use 2 examples per prompt
)

# Initialize GTICL
gticl = GTICL(llm_provider=llm_provider, config=gticl_config)

# Initialize TICL with matching parameters
ticl = TICL(
    llm_provider=llm_provider, 
    iterations=2,            # Match GTICL's iterations
    examples_per_prompt=2,   # Match GTICL's examples_per_prompt
    capacity=12               # Match GTICL's capacity
)

# Load the dataset into both
gticl.load_dataset(dataset=casual_emails_dataset)
ticl.load_dataset(casual_emails_dataset)

print("Both GTICL and TICL initialized with the same dataset and parameters")
# Out:
# INFO:gticl.gticl_writing:Loaded 12 samples into GTICL dataset
# INFO:ticl.ticl:Loaded 12 samples into TICL dataset
# Both GTICL and TICL initialized with the same dataset and parameters

# %% [markdown]
# ## Run Training
#
# Train both frameworks to collect negative samples and improve their understanding of the writing style.

# %%
# Function to time execution
def time_execution(fn, *args, **kwargs):
    start_time = time.time()
    result = fn(*args, **kwargs)
    end_time = time.time()
    execution_time = end_time - start_time
    return result, execution_time

# Run GTICL alignment
print("\n--- Running GTICL Alignment ---")
gticl_results, gticl_time = time_execution(
    gticl.run_alignment  # No task parameter needed now
)

# Run TICL
print("\n--- Running TICL Training ---")
ticl_results, ticl_time = time_execution(ticl.run)

# Compare training results
gticl_negative_samples = sum(len(samples) for samples in gticl.negative_samples_store.values())
ticl_negative_samples = sum(len(sample.generated_outputs) for sample in ticl.dataset)

print("\n--- Training Results ---")
print(f"GTICL Training Time: {gticl_time:.2f} seconds")
print(f"TICL Training Time: {ticl_time:.2f} seconds")
print(f"GTICL Negative Samples Collected: {gticl_negative_samples}")
print(f"TICL Negative Samples Collected: {ticl_negative_samples}")
# Out:
# INFO:gticl.gticl_writing:Starting iteration 1/2
# INFO:gticl.gticl_writing:Processing sample 1/12
# --- Running GTICL Alignment ---
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: that meeting yesterday...
#
# Hey Sam,
#
# What was up with Alex's idea yesterday?? A risky marketing push?? Seriously?
#
# I was thinking we should chat more about it. Wanna grab coffee tomorrow? I'm free after 2pm.
#
# Let me know!
# Jamie
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: that meeting yday...
#
# Hey Sam,
#
# What do you think about Alex's crazy marketing idea from yesterday? Seems kinda risky, right?
#
# I was wondering if you had time to grab coffee tomorrow and chat about it? Maybe after 2pm?
#
# Let me know if you're free.
#
# Talk soon,
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: that meeting yesterday...
#
# Hey Sam,
#
# What was up with Alex's idea yesterday?! A totally crazy marketing push, right? 😅
#
# I was wondering if you had time to grab coffee tomorrow and chat about it? Maybe after 2pm?
#
# Let me know if you're free.
#
# Talk soon,
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The sign-off "Talk soon, [Your Name]" should be removed, and the question "Seems kinda risky, right?" should be phrased as "Do you think we should go for it? Seems kinda risky to me, but then again, what do I know lol." to mirror the author's style. Also, 'yday' should be 'yesterday'.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The phrase "What was up with Alex's idea yesterday?? A risky marketing push?? Seriously?" should be rephrased to include "Sooo... that meeting yesterday was interesting, huh?" and "Not exactly what I expected!". The tone is more direct and less playful than the original. Also the sign off is missing.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The sign-off "Talk soon, [Your Name]" should be removed to mimic the author's style. The exclamation mark should be replaced with question mark: "A totally crazy marketing push, right?".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: that meeting yday...
#
# Hey Sam,
#
# What do you think about Alex's crazy marketing idea from yesterday? Seems kinda risky, right?
#
# I was wondering if you had time to grab coffee tomorrow and chat about it? Maybe after 2pm?
#
# Let me know if you're free.
#
# Talk soon,
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 2/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: SOS! Need your presentation expertise!
#
# Hey Taylor,
#
# Ugh, I'm officially stuck. 😫 I've been working on this presentation for like, 3 hours, and it's just not coming together.
#
# You're so much better at this stuff than I am! Any chance you could take a look and give me some feedback? I'd really appreciate it!
#
# Ideally, I'd love to get your thoughts by Friday.
#
# Thanks a bunch!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: help! need your presentation expertise
#
# Hey Taylor,
#
# Ugh, I've been working on this presentation for like 3 hours, and I'm still not happy with it. 😩 I'm starting to think I'm just making it worse, lol.
#
# You're way better at this stuff than I am – any chance you could take a look and give me some feedback? I'd really appreciate it!
#
# Ideally, I'd love to get your thoughts by Friday.
#
# Thanks a bunch!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: help! need your presentation expertise!
#
# Hey Taylor,
#
# Ugh, I've been working on this presentation for like, 3 hours now, and I'm totally stuck 😫. I'm starting to think it's just not gonna happen lol.
#
# You're way better at this stuff than I am, so I was hoping you could take a look? Any feedback would be amazing.
#
# Could you maybe give it a once-over by Friday?
#
# Thanks so much!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The subject line is too formal; it should be shorter and lowercase, like "help!". The closing should be "Thanks a million!" instead of "Thanks a bunch! [Your Name]". The emoji use is inconsistent with the author's style; use only one emoji at the end of the first paragraph.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The subject line should be shorter and only include one exclamation mark. The closing should be "Thanks a million!" instead of "Thanks so much!". The sentence structure is slightly more complex than the author's; simplify "Any feedback would be amazing" to "Just need someone to tell me if it makes sense or if I sound like I'm rambling."
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The closing should be "Thanks a million!" instead of "Thanks a bunch! [Your Name]".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: SOS! Need your presentation expertise!
#
# Hey Taylor,
#
# Ugh, I'm officially stuck. 😫 I've been working on this presentation for like, 3 hours, and it's just not coming together.
#
# You're so much better at this stuff than I am! Any chance you could take a look and give me some feedback? I'd really appreciate it!
#
# Ideally, I'd love to get your thoughts by Friday.
#
# Thanks a bunch!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 3/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: so sorry I missed our call!
#
# Hey!
#
# OMG, I am SO sorry I missed our call this morning. My alarm didn't go off (or maybe I hit snooze too many times 😬). Either way, totally my bad!
#
# Could we reschedule for tomorrow or Thursday? I'm free after lunch both days.
#
# Again, really sorry about that!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: so sorry I missed our call!
#
# Hey,
#
# OMG, I'm so sorry I missed our call this morning! My alarm didn't go off (or maybe I snoozed too many times 😬). Total disaster!
#
# Anyway, I wanted to apologize and see if we could reschedule. Are you free tomorrow or Thursday after lunch?
#
# Again, so sorry about this!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: so sorry I missed our call!
#
# Hey!
#
# OMG, I am SO sorry I missed our call this morning! My alarm didn't go off (or maybe I snoozed too many times 😬). Either way, totally my bad.
#
# Could we reschedule for tomorrow or Thursday? I'm free after lunch both days.
#
# Again, really sorry about that!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:This output is less stylistically consistent. It should remove the exclamation point in the greeting, remove "OMG," replace "SO" with "totally," remove the emoji, replace "totally my bad!" with "my bad," and remove signature.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:This output is mostly consistent, but it should remove the exclamation point in the greeting, replace "SO" with "totally," remove the emoji, replace "totally my bad!" with "my bad," and remove signature.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This output is stylistically consistent, mirroring the author's informal voice and brevity. Minor adjustments include replacing "Anyway" with "So" and omitting the signature.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: so sorry I missed our call!
#
# Hey!
#
# OMG, I am SO sorry I missed our call this morning. My alarm didn't go off (or maybe I hit snooze too many times 😬). Either way, totally my bad!
#
# Could we reschedule for tomorrow or Thursday? I'm free after lunch both days.
#
# Again, really sorry about that!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 4/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: project update :(
#
# Hey team,
#
# So, I have some bad news... we're not gonna hit the project deadline. 😩
#
# The backend stuff is taking way longer than we thought. I really thought we'd be done by now, but things keep popping up.
#
# I think we'll need another 1-2 weeks to get everything sorted. Wanna jump on a call and chat about options? Let me know what time works for you!
#
# Sorry about this!
# [Your name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: project update :(
#
# Hey team,
#
# So, not the email I wanted to send... 🙁
#
# Basically, we're gonna miss the project deadline. The backend stuff is taking way longer than we thought it would. I really thought we'd be good, but things keep popping up.
#
# I think we'll need another week or two to get everything sorted. Wanna jump on a call to chat about options? We can figure out the best way to move forward.
#
# Sorry about this!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: project update
#
# Hey team,
#
# Just wanted to give you a quick heads-up on the project. So, the backend stuff is taking waaaay longer than we thought. 🤦‍♀️
#
# Looks like I'm gonna miss the deadline. I'm thinking we'll need another week or two to get everything working properly.
#
# Happy to jump on a call and talk through options if anyone has thoughts.
#
# Sorry about this!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The writing lacks the author's casual tone. Replace "So, I have some bad news..." with "Ugh, I hate to be the bearer of bad news" and "backend stuff" with "backend issues." Shorten "I think we'll need another 1-2 weeks to get everything sorted" to "I'm thinking we need another week, maybe two?" Use an emoji after the first sentence. Replace "Sorry about this!" with "Thanks for understanding (hopefully lol)".
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The writing could be more stylistically consistent with the author's writing. Replace "Just wanted to give you a quick heads-up on the project" with "Sooo about that deadline..." as the subject. Shorten "the backend stuff is taking waaaay longer than we thought" to "The backend issues are taking wayyy longer to fix than we thought." Change "Looks like I'm gonna miss the deadline" to "we're gonna miss our target date" and add an emoji. Replace "Happy to jump on a call and talk through options if anyone has thoughts" with "Lemme know your thoughts. We can hop on a quick call if you wanna discuss options." Replace "Sorry about this!" with "Thanks for understanding (hopefully lol)".
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The writing is very close to the author's style, but could be improved by changing the subject to "sooo about that deadline...". Replace "not the email I wanted to send..." with "Ugh, I hate to be the bearer of bad news" and add an emoji. Shorten "The backend stuff is taking way longer than we thought it would" to "The backend issues are taking wayyy longer to fix than we thought". Change "I think we'll need another week or two to get everything sorted" to "I'm thinking we need another week, maybe two?" and add, "I know that's not what anyone wants to hear, but better to be realistic than promise something we can't deliver, right?". Replace "Sorry about this!" with "Thanks for understanding (hopefully lol)".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: project update :(
#
# Hey team,
#
# So, I have some bad news... we're not gonna hit the project deadline. 😩
#
# The backend stuff is taking way longer than we thought. I really thought we'd be done by now, but things keep popping up.
#
# I think we'll need another 1-2 weeks to get everything sorted. Wanna jump on a call and chat about options? Let me know what time works for you!
#
# Sorry about this!
# [Your name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 5/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: vacation request
#
# Hey [Boss's name],
#
# I'm writing to request a few days off. I was hoping to take vacation from May 15-19.
#
# I've been feeling a bit burnt out lately, and I think a short break would really help me recharge. I'll make sure to finish all my urgent tasks before I leave, and this is before the product launch, so it shouldn't cause any issues.
#
# Let me know if those dates work.
#
# Thanks!
# [Your name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: vacation request
#
# Hey [Boss's name],
#
# I'm writing to request some vacation time from May 15-19. I've been feeling a little burnt out lately, and I think a few days off would really help. 😓
#
# I know things are busy, but I promise this is before the product launch. I'll make sure all my work is totally finished before I go!
#
# Let me know if those dates work. Thanks! 😊
# [Your name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: Vacation Request
#
# Hey [Boss's name],
#
# I'm writing to request some vacation time from May 15-19. Feeling a bit burnt out lately! 🫠
#
# I'll make sure everything is wrapped up before I go, and this is before the product launch, so it shouldn't cause any issues.
#
# Let me know if that works!
#
# Thanks!
# [Your name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The subject line should be more casual (e.g., "vacation days next month??"). The phrase "Feeling a bit burnt out lately! 🫠" should be integrated more conversationally into the paragraph. The closing should include "a bunch" (e.g., "Thanks a bunch").
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The subject line should be more casual (e.g., "vacation days next month??"). Replace "I'm writing to request a few days off" with a more casual opening. The closing should include "a bunch" (e.g., "Thanks a bunch,").
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The subject line should be more casual (e.g., "vacation days next month??"). Add "Soooo" to the beginning of the email. The phrase "totally finished" should be changed to "all my stuff is done, obvi". The closing should include "a bunch" (e.g., "Thanks a bunch").
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: Vacation Request
#
# Hey [Boss's name],
#
# I'm writing to request some vacation time from May 15-19. Feeling a bit burnt out lately! 🫠
#
# I'll make sure everything is wrapped up before I go, and this is before the product launch, so it shouldn't cause any issues.
#
# Let me know if that works!
#
# Thanks!
# [Your name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 6/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: app crashing - urgent!
#
# Hey Dev Team,
#
# So, I've been testing the app and it's crashing like crazy. 😫 Keeps happening on the checkout page, like every 5 minutes.
#
# I've tried troubleshooting but no luck... I'm totally stumped. 🤷‍♀️
#
# We need this fixed ASAP - launch is tomorrow!
#
# Thanks!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: urgent - app crashing on checkout page!
#
# Hey Dev Team,
#
# So, I've been testing the app and it's crashing like crazy. 😭
#
# Specifically, it keeps crashing every 5 minutes when I'm on the checkout page. I've tried troubleshooting, but no luck. 🤷‍♀️
#
# We need this fixed ASAP - like, before tomorrow's launch!
#
# Thanks!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: urgent - app crashing on checkout page
#
# Hey Team,
#
# So, I've been testing the app, and it's crashing like crazy. 😫 It seems to happen every 5 minutes when I'm on the checkout page.
#
# I've tried troubleshooting, but no luck so far. 🤷‍♀️ Anyone have any ideas?
#
# We need this fixed ASAP since we're launching tomorrow!
#
# Thanks!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The subject line should be more casual like "umm our app is kinda broken??". The phrase "like crazy" should be replaced with "like every 5 minutes on the checkout page". Remove ellipsis after "luck". Replace "ASAP" with "asap". The signature should be "Jamie".
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The subject line should be more casual like "umm our app is kinda broken??". The phrase "like crazy" should be replaced with "like every 5 minutes on the checkout page". Remove "so far" after "luck". Replace "ASAP" with "asap". The phrase "Anyone have any ideas?" should be removed. The phrase "since we're launching tomorrow!" should be revised to something like "Customers are gonna freeeeak if this goes live tomorrow.". The signature should be "Jamie".
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The subject line should be more casual like "umm our app is kinda broken??". Replace "like crazy" with "like every 5 minutes on the checkout page". Replace "ASAP" with "asap". The phrase "like, before tomorrow's launch!" should be revised to something like "Customers are gonna freeeeak if this goes live tomorrow." The signature should be "Jamie".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: app crashing - urgent!
#
# Hey Dev Team,
#
# So, I've been testing the app and it's crashing like crazy. 😫 Keeps happening on the checkout page, like every 5 minutes.
#
# I've tried troubleshooting but no luck... I'm totally stumped. 🤷‍♀️
#
# We need this fixed ASAP - launch is tomorrow!
#
# Thanks!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 7/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: happy hour this week?
#
# Hey team,
#
# I know things have been crazy busy lately... 😓 Just wanted to see if anyone's up for a happy hour this Thursday?
#
# Thinking we could check out that new place on 5th street - I heard they have deals until 7. I'm happy to buy the first round!
#
# Totally get it if you're swamped, so no pressure either way. Just thought it might be nice to unwind a bit.
#
# Cheers!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: happy hour this week?
#
# Hey team,
#
# I know things have been crazy busy lately, so I was thinking maybe we could do a happy hour this week? 🤔
#
# There's a new place on 5th street that has deals until 7pm on Thursdays. I'm thinking of heading over there this Thursday. I'll buy the first round! 🍻
#
# Totally no pressure to come, but thought it might be a nice way to unwind.
#
# Later!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: happy hour this week?
#
# Hey team,
#
# I know everyone's been super busy lately... so I was thinking maybe we could do a happy hour this week? 🤷‍♀️
#
# There's a new place on 5th street that has deals until 7pm on Thursdays. I was thinking of checking it out, if anyone's interested. I'll buy the first round!
#
# Totally no pressure to come, but figured it could be a fun way to unwind a bit.
#
# Later!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:This email is the least stylistically consistent. To match the author's style, replace 'so I was thinking maybe we could do' with 'I think we deserve', include an emoji after 'week', and replace 'Later!' with 'Cheers!'
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:This email is stylistically consistent. To match the author's style more closely, add an emoji after 'break', and replace 'figured it could be a fun way to unwind a bit' with 'it'd be awesome to hang with you all outside this crazy office!' Also, replace 'Later!' with 'Cheers!'
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This email is stylistically consistent. To match the author's style more closely, add an emoji after 'break' and use 'Drop a quick reply' instead of 'Totally get it if you're swamped, so no pressure either way. Just thought it might be nice to unwind a bit.'
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: happy hour this week?
#
# Hey team,
#
# I know things have been crazy busy lately, so I was thinking maybe we could do a happy hour this week? 🤔
#
# There's a new place on 5th street that has deals until 7pm on Thursdays. I'm thinking of heading over there this Thursday. I'll buy the first round! 🍻
#
# Totally no pressure to come, but thought it might be a nice way to unwind.
#
# Later!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 8/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: Sarah's birthday next Friday!
#
# Hey team,
#
# So, next Friday is Sarah's birthday! 🎉
#
# I was thinking we could decorate her desk before she gets in (she's usually late anyway lol). Then maybe grab lunch at that Thai place she loves? 😋
#
# Also, wanna all chip in for a plant or something?
#
# Let me know what you think!
# Best,
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: Sarah's birthday next week! 🎉
#
# Hey team,
#
# So, Sarah's birthday is next Friday! Let's make it awesome for her. 😄
#
# I was thinking we could decorate her desk before she gets in (she's always late anyway lol). Also, maybe grab lunch at that Thai place she loves? 🍜
#
# And, we should all chip in to get her a plant or something. Any thoughts?
#
# Let me know if you're in!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: Sarah's birthday next week!
#
# Hey team,
#
# Just a heads-up that it's Sarah's birthday next Friday! 🎉
#
# I was thinking we could decorate her desk before she gets in (she's always late anyway lol), grab lunch at that Thai place she loves, and maybe chip in for a plant? 🪴
#
# Let me know if you're in!
#
# Thanks!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:This output is the least stylistically consistent. To be more consistent, add more exclamation points in the subject line, replace "So, next Friday is" with "Sooo it's", remove the word "Also", and replace "Best" with "Thx!".
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:This output includes some stylistic inconsistencies. To be more consistent, add more exclamation points to the subject line, replace "So, Sarah's birthday is" with "Sooo it's", remove the word "also", replace "And, we should all" with "Anyone wanna", and replace "Any thoughts?" with a direct call to action like "Let me know if you're in!".
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This output is the most stylistically consistent. To be more consistent, replace "Just a heads-up that it's" with "Sooo it's", add an additional exclamation point to the subject line, remove the word "maybe", and replace "Thanks!" with "Thx!".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: Sarah's birthday next Friday!
#
# Hey team,
#
# So, next Friday is Sarah's birthday! 🎉
#
# I was thinking we could decorate her desk before she gets in (she's usually late anyway lol). Then maybe grab lunch at that Thai place she loves? 😋
#
# Also, wanna all chip in for a plant or something?
#
# Let me know what you think!
# Best,
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 9/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: Team Building - Escape Room & Dinner? 🧟
#
# Hey everyone,
#
# So I was thinking... for our next team-building thing, how about we hit up that zombie escape room downtown? Seems like it could be a laugh! 🤣
#
# Afterwards, we could grab some dinner somewhere. Plus-ones are totally welcome too!
#
# To make the booking for next Friday after work, I kinda need to know who's in by Tuesday. Let me know if you're interested!
#
# Cheers!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: Team building idea! 🧟
#
# Hey everyone,
#
# So I was thinking... for our next team-building thing, how about a zombie escape room downtown? I saw it online and it looks SO fun! 🤩
#
# Afterwards, we could grab dinner somewhere nearby. And feel free to bring a plus-one!
#
# Let me know if you're in by Tuesday so I can book it. Thinking next Friday after work?
#
# Cheers!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: Team Building Idea - Zombies?! 🧟
#
# Hey everyone,
#
# So, I was thinking about our next team-building thing and had an idea... How about a zombie escape room downtown? I saw one that looks super fun (and maybe a little scary lol).
#
# Afterwards, we could grab dinner somewhere nearby. Plus-ones are totally welcome!
#
# If you're in, let me know by Tuesday so I can book it for next Friday after work.
#
# Later!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:To better align with the author's style, replace "Hey everyone" with "Hey all", add "🔎" after "team-building thing", replace "Seems like it could be a laugh! 🤣" with "'s supposed to be AMAZING. They have this zombie apocalypse theme that sounds super fun (and kinda terrifying tbh)", and change "Cheers!" to "Can't wait!\nJordan". Remove "Your Name".
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:To better match the author's style, replace "Hey everyone" with "Hey all", add "🔎" after "thing and had an idea", replace "looks super fun (and maybe a little scary lol)" with "'s supposed to be AMAZING. They have this zombie apocalypse theme that sounds super fun (and kinda terrifying tbh)", and change "Later!" to "Can't wait!\nJordan".
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This email closely matches the author's style. To align even better, replace "Hey everyone" with "Hey all", add "🔎" after "team thing??", replace "SO fun! 🤩" with "AMAZING. They have this zombie apocalypse theme that sounds super fun (and kinda terrifying tbh)", and change "Cheers!" to "Can't wait!\nJordan".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: Team Building - Escape Room & Dinner? 🧟
#
# Hey everyone,
#
# So I was thinking... for our next team-building thing, how about we hit up that zombie escape room downtown? Seems like it could be a laugh! 🤣
#
# Afterwards, we could grab some dinner somewhere. Plus-ones are totally welcome too!
#
# To make the booking for next Friday after work, I kinda need to know who's in by Tuesday. Let me know if you're interested!
#
# Cheers!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 10/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: I'M COMING TO VISIT!!!
#
# OMG HIIIIII!
#
# Guess what?! I'm coming to your neck of the woods from May 10-15! 🎉 I'm SO excited!
#
# I saw that brunch place you posted about... we HAVE to go! Looks delish. 🤤
#
# Also, any chance I could crash at your place for a few nights? Hotels are $$$. I'll bring your fave cookies! 🍪🍪🍪
#
# Can't wait to see you!
# Jess
# INFO:gticl.gticl_writing:Candidate 2/3: '''
# Subject: Guess what?! I'm coming to your neck of the woods!
#
# Hey [Friend's Name],
#
# OMG, guess what?! I'm planning a trip to your area from May 10-15! 🎉
#
# I saw your post about that brunch place, [Brunch Place Name]... we HAVE to try it! 🤤
#
# Also, any chance I could crash at your place for a few nights? Hotels are crazy expensive! I promise to bring your fave cookies! 🍪🍪
#
# Can't wait to see you!
# [Your Name]
# '''
# INFO:gticl.gticl_writing:Candidate 3/3: '''
# Subject: Omg guess what?! I'm coming to see you!
#
# Hey [Friend's name],
#
# You are not going to believe this... I booked a trip to your neck of the woods! 🎉 I'll be there May 10-15.
#
# I saw your post about that brunch place the other day - we HAVE to try it! 🤤
#
# Also... any chance I could crash at your place for a few nights? Hotels are $$$, and I'd love to hang out more! I'll bring your fave cookies! 🍪🍪
#
# Can't wait!
# [Your name]
# '''
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:This candidate is the least consistent. To align with the author's style, it needs more exclamation points, emojis, and less formal language, such as omitting 'You are not going to believe this...' and replacing it with something more casual. Also, it should add more 'y's to the opening greeting and closing.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The writing is mostly consistent, but could be improved by using more 'y's in 'Hey' and 'see you'. Also, the omission of the airplane emoji and the exclamation points after 'soooo excited' negatively impacts the consistency.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This output is the most stylistically consistent. It captures the author’s excited tone, frequent use of exclamation points and emojis, and informal language. It could be further improved by adding more 'y's to the opening greeting, as well as the closing, to match the author's specific style.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: '''
# Subject: Omg guess what?! I'm coming to see you!
#
# Hey [Friend's name],
#
# You are not going to believe this... I booked a trip to your neck of the woods! 🎉 I'll be there May 10-15.
#
# I saw your post about that brunch place the other day - we HAVE to try it! 🤤
#
# Also... any chance I could crash at your place for a few nights? Hotels are $$$, and I'd love to hang out more! I'll bring your fave cookies! 🍪🍪
#
# Can't wait!
# [Your name]
# '''
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 11/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: OMG I'm so sorry!!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was off the grid all day. Seriously the worst timing ever!
#
# Please tell me you can forgive me?! 🙏 I feel like such a bad friend.
#
# How about I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: OMG I'm so sorry!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was totally off the grid all day. Seriously the worst timing ever!
#
# Please forgive me! 🙏 I feel like such a bad friend.
#
# How about I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: OMG I'm so sorry!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was off the grid all day. Seriously, the WORST timing ever!
#
# I feel terrible. Can I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry! Hope you had an amazing day anyway! ❤️
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The writing is more formal than the original. Replace "I am SO sorry" with "Omg I'm so sorry!!", add "(classic me, right?)" after "My phone died", replace "Please tell me you can forgive me?!" with "Pretty please forgive me?", and replace "[Your Name]" with "Love youuuu!, Taylor" for better consistency.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The writing is more formal than the original. Replace "I am SO sorry" with "Omg I'm so sorry!!", add "(classic me, right?)" after "My phone died", replace "I feel terrible" with "You know I'd never forget on purpose, right? You're literally my favorite human!", replace "Again, I'm really sorry! Hope you had an amazing day anyway! ❤️ [Your Name]" with "Love youuuu!, Taylor" for better consistency.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The writing is more formal than the original. Replace "I am SO sorry" with "Omg I'm so sorry!!", add "(classic me, right?)" after "My phone died", replace "Please forgive me!" with "Pretty please forgive me?", and replace "[Your Name]" with "Love youuuu!, Taylor" for better consistency.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: OMG I'm so sorry!!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was off the grid all day. Seriously the worst timing ever!
#
# Please tell me you can forgive me?! 🙏 I feel like such a bad friend.
#
# How about I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 12/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: veggie sandwich issue
#
# Hey there,
#
# So, I stopped by yesterday around 3pm and got a veggie sandwich. Was really looking forward to it!
#
# But I unfortunately found some bacon in it. 😬 I'm vegetarian, so that was a bummer.
#
# I've heard great things about your food, so I'd still like to come back. Any chance I could get a refund or exchange on the sandwich?
#
# Thanks!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: veggie sandwich issue :(
#
# Hey [Store Name],
#
# So, I got a veggie sandwich from you guys yesterday around 3pm. I've heard your food is amazing, which is why I wanted to try it!
#
# But... I found bacon in my veggie sandwich. 😭 I'm a vegetarian, so I couldn't eat it.
#
# I'd still like to come back sometime (since everyone raves about your food!), but is there any way I could return the sandwich?
#
# Thanks!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: veggie sandwich issue :(
#
# Hey [Store Name],
#
# So, I got a veggie sandwich from you guys yesterday around 3pm. I've heard great things about your food!
#
# But, I found bacon in it... which isn't ideal since I don't eat meat. 🥲
#
# I'd still love to come back - is there any way I could return it?
#
# Thanks!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:This output is the least consistent with the author's style. Adding "Sooo" to the beginning of the email, adding "lol" to the end of the second paragraph, and replacing "Any chance I could get a refund or exchange on the sandwich?" with "I'd love to come back and try again since everyone says your food is amazing" would improve it.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:This output is good, but lacks some of the author's stylistic choices. Adding "Sooo" to the beginning of the email, adding "lol" to the end of the second paragraph, and replacing "I'd still love to come back - is there any way I could return it?" with "I'd love to come back and try again since everyone says your food is amazing" would improve it.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This output captures the author's tone well. Adding "Sooo" to the beginning of the email, replacing "But..." with "But" and adding "lol" to the end of the second paragraph, and replacing "is there any way I could return the sandwich?" with "I'd love to come back and try again" would make it more consistent with the author's writing.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: veggie sandwich issue
#
# Hey there,
#
# So, I stopped by yesterday around 3pm and got a veggie sandwich. Was really looking forward to it!
#
# But I unfortunately found some bacon in it. 😬 I'm vegetarian, so that was a bummer.
#
# I've heard great things about your food, so I'd still like to come back. Any chance I could get a refund or exchange on the sandwich?
#
# Thanks!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Starting iteration 2/2
# INFO:gticl.gticl_writing:Processing sample 1/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: that meeting yesterday...
#
# Hey Sam,
#
# What was up with Alex's idea yesterday? A risky marketing push seems kinda wild, right?
#
# I was wondering if you had any thoughts? Maybe we could grab coffee tomorrow and chat about it? I'm free after 2pm.
#
# Let me know!
# Jamie
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: that meeting yesterday...
#
# Hey Sam,
#
# What was up with Alex's idea yesterday?! A risky marketing push like that? 😬
#
# I was wondering if you'd be down to grab coffee tomorrow and chat about it? Maybe after 2pm?
#
# Let me know if you're free.
#
# Talk soon,
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: that meeting yesterday...
#
# Hey Sam,
#
# What do you think about Alex's idea from yesterday? A new marketing push seems kinda risky, right?
#
# I was wondering if you'd be down to grab coffee tomorrow and chat about it more? I'm free after 2pm.
#
# Let me know if you're interested!
# Jamie
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:This output lacks the casual tone and interjections present in the author's writing. Add interjections like "Sooo..." and "lol", rephrase questions to be more casual, and replace "Let me know if you're interested!" with "Later!".
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The writing lacks the author's characteristic interjections and casual tone. Add "Sooo..." at the beginning, replace "What was up with" with "Sooo...what was up with", include interjections like "huh?" or "lol", and replace "Let me know!" with "Later!".
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This output closely matches the author's style with its use of interjections and casual language. Replace "Talk soon, [Your Name]" with "Later!".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: that meeting yesterday...
#
# Hey Sam,
#
# What do you think about Alex's idea from yesterday? A new marketing push seems kinda risky, right?
#
# I was wondering if you'd be down to grab coffee tomorrow and chat about it more? I'm free after 2pm.
#
# Let me know if you're interested!
# Jamie
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 2/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: help! need your presentation expertise
#
# Hey Taylor,
#
# Ugh, I've been working on this presentation for like, 3 hours, and I'm officially stuck. 😩
#
# You're so much better at this stuff than I am! Any chance you could take a look and give me some feedback? I'd really appreciate it!
#
# Ideally, I'd love to get your thoughts by Friday.
#
# Thanks a bunch!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: help! need ur feedback on this presentation
#
# Hey Taylor,
#
# Ugh, I've been staring at this presentation for like 3 hours now, and I'm officially stuck. 😩
#
# You're way better at this stuff than I am, so I was hoping you could take a look and give me some feedback? I'm trying to get it done by Friday.
#
# Let me know if you can help!
# Thanks!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: help! need your feedback on this presentation
#
# Hey Taylor,
#
# Ugh, I've been working on this presentation for like, three hours now, and I'm totally stuck. 😩
#
# You're way better at this stuff than I am, so I was hoping you could take a look and give me some feedback? I'd really appreciate it!
#
# Ideally, I'd love to get your thoughts by Friday.
#
# Thanks in advance!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The style is less consistent. To more closely resemble the author's style, remove "[Your Name]", change "Ugh, I've" to "I'm", replace "three" with "3", replace "so much better" with "way better", and use "tho" instead of "Ideally". Also, change "Thanks in advance!" to "Thanks a million!"
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The style is mostly consistent. To better match the author's style, remove "[Your Name]", change "Ugh, I've" to "I'm", replace "so much better" with "way better", and use "tho" instead of "Ideally".
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This output closely matches the author's style, using similar language, sentence structure, and punctuation. To align even closer, remove "[Your Name]" and change "ur" to "your".
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: help! need your feedback on this presentation
#
# Hey Taylor,
#
# Ugh, I've been working on this presentation for like, three hours now, and I'm totally stuck. 😩
#
# You're way better at this stuff than I am, so I was hoping you could take a look and give me some feedback? I'd really appreciate it!
#
# Ideally, I'd love to get your thoughts by Friday.
#
# Thanks in advance!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 3/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: so sorry I missed our call!
#
# Hey,
#
# OMG, I am SO sorry I missed our call this morning! My alarm didn't go off (or maybe I hit snooze one too many times 😬). Either way, totally my fault.
#
# Could we reschedule for tomorrow or Thursday? I'm free after lunch both days.
#
# Again, really sorry about that!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: so sorry I missed our call!
#
# Hey!
#
# OMG, I am SO sorry I missed our call this morning! 🤦‍♀️ My alarm didn't go off (or maybe I snoozed one too many times... whoops!).
#
# Totally my bad. Wanna reschedule for tomorrow or Thursday? I'm free after lunch both days.
#
# Let me know what works!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: so sorry I missed our call!
#
# Hey!
#
# OMG, I am SO sorry I missed our call this morning! My alarm didn't go off (or maybe I hit snooze one too many times 🙈 ). Total disaster, I know.
#
# Anyway, super unprofessional of me, and I feel terrible.
#
# Could we reschedule for tomorrow or Thursday after lunch? Let me know what works for you!
#
# Again, so sorry!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The writing diverges somewhat from the author's style. The phrases "Total disaster, I know" and "super unprofessional of me, and I feel terrible" introduce a level of formality and length not present in the original. The author's name should be removed from the closing.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The writing is mostly consistent, but some elements could be adjusted. The use of "SO sorry" and the emoji align with the author's style. Consider removing "one" from "hit snooze one too many times" to match the original's phrasing. The closing could be more casual; removing "[Your Name]" would be more consistent.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The writing is consistent with the author's style, especially in its brevity and casual tone. The use of "Hey!", "OMG", and emojis align well. The phrase "Totally my bad" mirrors the original's "my bad." The suggestion to "Wanna reschedule" maintains the informal voice. Adding a name is not a feature of the original.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: so sorry I missed our call!
#
# Hey!
#
# OMG, I am SO sorry I missed our call this morning! My alarm didn't go off (or maybe I hit snooze one too many times 🙈 ). Total disaster, I know.
#
# ...
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: OMG - I'm coming your way!!
#
# Hey [Friend's Name],
#
# Guess what?! I'm planning a trip to your neck of the woods from May 10-15! 🎉
#
# I saw that brunch place you posted about - we HAVE to try it! 🤤
#
# Also, hotels are crazy expensive... any chance I could crash at your place for a few nights? I promise to bring your fave cookies! 🍪🍪🍪
#
# Can't wait to see you!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: Guess what?! I'm coming to visit!
#
# Hey [Friend's Name],
#
# OMG, guess what?! I'm planning a trip to your neck of the woods from May 10-15! 🎉
#
# I saw that brunch place you posted about the other day... we HAVE to try it! 🤤
#
# Also, would it be cool if I crashed at your place for a few nights? Hotels are so expensive, ugh. I'll bring your fave cookies! 🍪🍪
#
# Can't wait to see you!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: Omg I'm coming to see you!!
#
# Hey [Friend's Name],
#
# Guess what?! I'm coming to your neck of the woods from May 10-15! 🎉 So excited!
#
# I saw that brunch place you posted about... we HAVE to go. Looks delish! 😋
#
# Also, hotels are $$$... any chance I could crash at your place for a few nights? I promise to bring your fave cookies! 🍪🍪
#
# Can't wait to see you!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The subject line should be more enthusiastic with multiple exclamation points. The opening should include "Heyyyy!". The abbreviation "rn" and "soooo" should be used. Shorten "we HAVE to try it!" to "those pancakes looked INSANE." Add "Can't wait to see youuuu!"
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The subject line should be more enthusiastic with multiple exclamation points. The opening should include "Heyyyy!". The abbreviation "rn" and "soooo" should be used. Shorten "Looks delish!" to "looked INSANE." Add "Can't wait to see youuuu!"
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:This is the closest stylistically. The subject line should be more enthusiastic with multiple exclamation points. The opening should include "Heyyyy!". The abbreviation "rn" and "soooo" should be used. Add "Can't wait to see youuuu!"
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: Guess what?! I'm coming to visit!
#
# Hey [Friend's Name],
#
# OMG, guess what?! I'm planning a trip to your neck of the woods from May 10-15! 🎉
#
# I saw that brunch place you posted about the other day... we HAVE to try it! 🤤
#
# Also, would it be cool if I crashed at your place for a few nights? Hotels are so expensive, ugh. I'll bring your fave cookies! 🍪🍪
#
# Can't wait to see you!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 11/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: OMG I'm so sorry!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was totally off the grid all day. Seriously the WORST timing ever!
#
# I feel like such a bad friend. 💔 Can I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: OMG I'm so sorry!!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was off the grid all day. Seriously, the WORST timing ever.
#
# I feel terrible! How about I make it up to you with dinner at that new Italian place next week? My treat, of course! 🥂
#
# Again, so sorry! Hope you had an amazing day anyway!
#
# Talk soon,
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: OMG I'm so sorry!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was totally off the grid all day. Seriously, the WORST timing ever.
#
# I feel terrible! 🤦‍♀️
#
# How about I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The writing is too formal. The emoji usage is inconsistent with the author. The author uses more exclamation points. The sign-off is too formal; replace "[Your Name]" with "Taylor".
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The writing is too formal. The author uses more emojis and exclamation points. The sign-off is too formal; replace "[Your Name]" with "Taylor". The sentence "You know I'd never forget on purpose, right? You're literally my favorite human!" is missing.
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The writing is slightly too formal. The author uses more emojis. The sign-off is too formal; replace "[Your Name]" with "Taylor". The sentence "You know I'd never forget on purpose, right? You're literally my favorite human!" is missing.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: OMG I'm so sorry!
#
# Hey [Friend's Name],
#
# I am SO sorry I missed your birthday yesterday! 😭 My phone died and I was totally off the grid all day. Seriously, the WORST timing ever.
#
# I feel terrible! 🤦‍♀️
#
# How about I make it up to you with dinner at that new Italian place next week? My treat, of course!
#
# Again, I'm really sorry!
# [Your Name]
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Processing sample 12/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Subject: veggie sandwich issue
#
# Hey,
#
# So, I got a veggie sandwich from your store yesterday around 3pm, and I think there may have been some bacon in it? 😬
#
# I'm vegetarian, so I was a little bummed out. I'd still like to return sometime this week, though! I've heard your food is usually amazing.
#
# Thanks!
# Lee
# INFO:gticl.gticl_writing:Candidate 2/3: Subject: veggie sandwich issue :(
#
# Hey there,
#
# So, I stopped by yesterday around 3 and got a veggie sandwich. Everyone says your food is amazing!
#
# But I found bacon in it... I'm veggie, so that wasn't ideal lol. 😬
#
# I was wondering if I could still return it? I'd love to give you guys another shot sometime!
#
# Thanks!
# [Your Name]
# INFO:gticl.gticl_writing:Candidate 3/3: Subject: veggie sandwich issue :(
#
# Hey there,
#
# So I stopped by yesterday around 3pm and got a veggie sandwich. I've heard great things about your food!
#
# But when I started eating it, I found some bacon inside. I'm vegetarian, so that was kinda a bummer. 🥲
#
# I'd still like to give you guys another shot, is it cool if I return it?
#
# Thanks!
# Jordan
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:gticl.gticl_writing:Candidate 1/3: Explanation:The output lacks the author's characteristic informality and humor. To align more closely, the subject line should have a more casual tone and include an emoticon like the author's. It needs more casual diction (e.g., replace "bummed out" with "not ideal lol"), and the closing should be "All the best" followed by the author's name.
#  (Rank: 3)
# INFO:gticl.gticl_writing:Candidate 2/3: Explanation:The output captures the author's style through its use of emoticons and sentence structure. To align even closer, the subject line should match the author's more casual tone, and the closing should be "All the best" followed by the author's name. The phrase "kinda a bummer" could be more casual, like "not ideal."
#  (Rank: 2)
# INFO:gticl.gticl_writing:Candidate 3/3: Explanation:The output closely mimics the author's style through its use of emoticons, sentence structure, and diction (e.g., "Hey there," "lol," "wasn't ideal"). To align even closer, the subject line should match the author's more casual tone, and the closing should be "All the best" followed by the author's name.
#  (Rank: 1)
# INFO:gticl.gticl_writing:Negative Sample 1/1: Subject: veggie sandwich issue
#
# Hey,
#
# So, I got a veggie sandwich from your store yesterday around 3pm, and I think there may have been some bacon in it? 😬
#
# I'm vegetarian, so I was a little bummed out. I'd still like to return sometime this week, though! I've heard your food is usually amazing.
#
# Thanks!
# Lee
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Starting TICL iteration 1/2
# INFO:ticl.ticl:Processing sample 1/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Running TICL Training ---
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 1
# INFO:ticl.ticl:Processing sample 2/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 2
# INFO:ticl.ticl:Processing sample 3/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 3
# INFO:ticl.ticl:Processing sample 4/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 4
# INFO:ticl.ticl:Processing sample 5/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 5
# INFO:ticl.ticl:Processing sample 6/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 6
# INFO:ticl.ticl:Processing sample 7/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 7
# INFO:ticl.ticl:Processing sample 8/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 8
# INFO:ticl.ticl:Processing sample 9/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 9
# INFO:ticl.ticl:Processing sample 10/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 10
# INFO:ticl.ticl:Processing sample 11/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 11
# INFO:ticl.ticl:Processing sample 12/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 12
# INFO:ticl.ticl:Starting TICL iteration 2/2
# INFO:ticl.ticl:Processing sample 1/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 1
# INFO:ticl.ticl:Processing sample 2/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 2
# INFO:ticl.ticl:Processing sample 3/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 3
# INFO:ticl.ticl:Processing sample 4/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 4
# INFO:ticl.ticl:Processing sample 5/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 5
# INFO:ticl.ticl:Processing sample 6/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 6
# INFO:ticl.ticl:Processing sample 7/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 7
# INFO:ticl.ticl:Processing sample 8/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 8
# INFO:ticl.ticl:Processing sample 9/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 9
# INFO:ticl.ticl:Processing sample 10/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 10
# INFO:ticl.ticl:Processing sample 11/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 11
# INFO:ticl.ticl:Processing sample 12/12
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ticl.ticl:Adding negative sample for sample 12
# --- Training Results ---
# GTICL Training Time: 184.75 seconds
# TICL Training Time: 77.93 seconds
# GTICL Negative Samples Collected: 24
# TICL Negative Samples Collected: 24

# %% [markdown]
# ## Compare Negative Samples Storage
#
# Let's examine how GTICL and TICL store their negative samples after training.

# %%
import pprint
from tabulate import tabulate

pp = pprint.PrettyPrinter(indent=2, width=120)

print("\n===== GTICL Storage Details =====\n")
print(f"Number of tasks with negative samples: {len(gticl.negative_samples_store)}")

for task, samples in gticl.negative_samples_store.items():
    print(f"\nTask: {task}")
    print(f"Number of negative samples: {len(samples)}")
    
    data = []
    for i, sample in enumerate(samples):
        # Format candidate and explanation for better readability
        candidate = sample['candidate'].replace('\n', '\n  ')[:100] + "..." if len(sample['candidate']) > 100 else sample['candidate']
        explanation = sample['explanation'].replace('\n', '\n  ')[:100] + "..." if len(sample['explanation']) > 100 else sample['explanation']
        
        data.append([f"Sample {i+1}", candidate, explanation])
    
    print(tabulate(data, headers=["ID", "Candidate (truncated)", "Explanation (truncated)"], tablefmt="grid"))
    
    # Show discarded samples summary if any
    if gticl.negative_samples_summary.get(task):
        print("\nDiscarded Samples Summary:")
        print(gticl.negative_samples_summary[task])

print("\n\n===== TICL Storage Details =====\n")
print(f"Number of samples with negative examples: {sum(1 for sample in ticl.dataset if len(sample.generated_outputs) > 0)}")

for i, sample in enumerate(ticl.dataset):
    if len(sample.generated_outputs) > 0:
        print(f"\nSample {i+1}: {sample.task[:50]}...")
        print(f"Number of negative outputs: {len(sample.generated_outputs)}")
        
        data = []
        for j, neg in enumerate(sample.generated_outputs):
            # Format output and explanation for better readability
            output = neg.output.replace('\n', '\n  ')[:100] + "..." if len(neg.output) > 100 else neg.output
            explanation = neg.explanation.replace('\n', '\n  ')[:100] + "..." if len(neg.explanation) > 100 else neg.explanation
            
            data.append([f"Negative {j+1}", output, explanation])
        
        print(tabulate(data, headers=["ID", "Output (truncated)", "Explanation (truncated)"], tablefmt="grid"))

# Show discarded samples for TICL if any
if hasattr(ticl, "discarded_samples") and ticl.discarded_samples:
    print("\n\nTICL Discarded Samples:")
    for task, samples in ticl.discarded_samples.items():
        print(f"\nTask: {task[:50]}...")
        print(f"Number of discarded samples: {len(samples)}")
        pp.pprint(samples)

print("\n\n===== Storage Comparison =====\n")
print(f"GTICL total negative samples: {sum(len(samples) for samples in gticl.negative_samples_store.values())}")
print(f"TICL total negative samples: {sum(len(sample.generated_outputs) for sample in ticl.dataset)}")
# Out:
# ===== GTICL Storage Details =====
#
# Number of tasks with negative samples: 12
#
# Task: Write a casual email to Sam discussing yesterday's meeting where Alex proposed a risky new marketing push. Suggest meeting for coffee tomorrow after 2pm to discuss it further.
# Number of negative samples: 2
# +----------+----------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                                    | Explanation (truncated)                                                                                 |
# +==========+==========================================================+=========================================================================================================+
# | Sample 1 | Subject: that meeting yday...                            | The sign-off "Talk soon, [Your Name]" should be removed, and the question "Seems kinda risky, right?... |
# |          |                                                          |                                                                                                         |
# |          |   Hey Sam,                                               |                                                                                                         |
# |          |                                                          |                                                                                                         |
# |          |   What do you think about Alex's crazy marketing idea... |                                                                                                         |
# +----------+----------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: that meeting yesterday...                       | This output lacks the casual tone and interjections present in the author's writing. Add interjectio... |
# |          |                                                          |                                                                                                         |
# |          |   Hey Sam,                                               |                                                                                                         |
# |          |                                                          |                                                                                                         |
# |          |   What do you think about Alex's idea from yeste...      |                                                                                                         |
# +----------+----------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email to Taylor asking for feedback on a presentation you've been struggling with for 3 hours. Mention you need their help because they're better at this, and you'd appreciate feedback by Friday.
# Number of negative samples: 2
# +----------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                                  | Explanation (truncated)                                                                                 |
# +==========+========================================================+=========================================================================================================+
# | Sample 1 | Subject: SOS! Need your presentation expertise!        | The subject line is too formal; it should be shorter and lowercase, like "help!". The closing should... |
# |          |                                                        |                                                                                                         |
# |          |   Hey Taylor,                                          |                                                                                                         |
# |          |                                                        |                                                                                                         |
# |          |   Ugh, I'm officially stuck. 😫 I...                   |                                                                                                         |
# +----------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: help! need your feedback on this presentation | The style is less consistent. To more closely resemble the author's style, remove "[Your Name]", cha... |
# |          |                                                        |                                                                                                         |
# |          |   Hey Taylor,                                          |                                                                                                         |
# |          |                                                        |                                                                                                         |
# |          |   Ugh, I've been working ...                           |                                                                                                         |
# +----------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email apologizing for missing a scheduled call this morning because your alarm didn't go off (or you hit snooze too many times). Suggest rescheduling for tomorrow or Thursday after lunch.
# Number of negative samples: 2
# +----------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                                 | Explanation (truncated)                                                                                 |
# +==========+=======================================================+=========================================================================================================+
# | Sample 1 | Subject: so sorry I missed our call!                  | This output is less stylistically consistent. It should remove the exclamation point in the greeting... |
# |          |                                                       |                                                                                                         |
# |          |   Hey!                                                |                                                                                                         |
# |          |                                                       |                                                                                                         |
# |          |   OMG, I am SO sorry I missed our call this mornin... |                                                                                                         |
# +----------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: so sorry I missed our call!                  | The writing diverges somewhat from the author's style. The phrases "Total disaster, I know" and "sup... |
# |          |                                                       |                                                                                                         |
# |          |   Hey!                                                |                                                                                                         |
# |          |                                                       |                                                                                                         |
# |          |   OMG, I am SO sorry I missed our call this mornin... |                                                                                                         |
# +----------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email to your team explaining that you'll miss the project deadline due to backend issues taking longer than expected. Suggest you need 1-2 more weeks and offer to discuss options on a call.
# Number of negative samples: 2
# +----------+------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                                      | Explanation (truncated)                                                                                 |
# +==========+============================================================+=========================================================================================================+
# | Sample 1 | Subject: project update :(                                 | The writing lacks the author's casual tone. Replace "So, I have some bad news..." with "Ugh, I hate ... |
# |          |                                                            |                                                                                                         |
# |          |   Hey team,                                                |                                                                                                         |
# |          |                                                            |                                                                                                         |
# |          |   So, I have some bad news... we're not gonna hit the p... |                                                                                                         |
# +----------+------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: Project Update - Running Behind                   | This output is the least aligned with the author's style because it uses more formal language and la... |
# |          |                                                            |                                                                                                         |
# |          |   Hey Team,                                                |                                                                                                         |
# |          |                                                            |                                                                                                         |
# |          |   Just wanted to give you a heads-up on t...               |                                                                                                         |
# +----------+------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email to your boss requesting vacation days from May 15-19 because you're feeling burnt out. Assure them this is before the product launch and you'll have your work completed before leaving.
# Number of negative samples: 2
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                              | Explanation (truncated)                                                                                 |
# +==========+====================================================+=========================================================================================================+
# | Sample 1 | Subject: Vacation Request                          | The subject line should be more casual (e.g., "vacation days next month??"). The phrase "Feeling a b... |
# |          |                                                    |                                                                                                         |
# |          |   Hey [Boss's name],                               |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   I'm writing to request some vacation time fro... |                                                                                                         |
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: Vacation Request - May 15-19              | This writing needs significant changes: The subject line should include a question mark and remove e... |
# |          |                                                    |                                                                                                         |
# |          |   Hey [Boss's name],                               |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   I'm writing to request a few vaca...             |                                                                                                         |
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email to the dev team about app issues you discovered during testing, where it crashes every 5 minutes on the checkout page. Mention you've tried troubleshooting with no success and need this fixed before tomorrow's launch.
# Number of negative samples: 2
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                              | Explanation (truncated)                                                                                 |
# +==========+====================================================+=========================================================================================================+
# | Sample 1 | Subject: app crashing - urgent!                    | The subject line should be more casual like "umm our app is kinda broken??". The phrase "like crazy"... |
# |          |                                                    |                                                                                                         |
# |          |   Hey Dev Team,                                    |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   So, I've been testing the app and it's crash...  |                                                                                                         |
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: urgent - app crashing on checkout page 🚨 | The subject line should be less formal (e.g., "umm our app is kinda broken??"). Remove "team," chang... |
# |          |                                                    |                                                                                                         |
# |          |   Hey team,                                        |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   So, I've been testing the app ...                |                                                                                                         |
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email to your overworked team suggesting a happy hour this Thursday at the new place on 5th street that has deals until 7pm. Offer to buy the first round and make it clear there's no pressure to attend.
# Number of negative samples: 2
# +----------+---------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                                   | Explanation (truncated)                                                                                 |
# +==========+=========================================================+=========================================================================================================+
# | Sample 1 | Subject: happy hour this week?                          | This email is the least stylistically consistent. To match the author's style, replace 'so I was thi... |
# |          |                                                         |                                                                                                         |
# |          |   Hey team,                                             |                                                                                                         |
# |          |                                                         |                                                                                                         |
# |          |   I know things have been crazy busy lately, so I w...  |                                                                                                         |
# +----------+---------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: happy hour this week?                          | The writing is too formal and uses complete sentences, unlike the original. To align with the author... |
# |          |                                                         |                                                                                                         |
# |          |   Hey team,                                             |                                                                                                         |
# |          |                                                         |                                                                                                         |
# |          |   I know things have been crazy busy lately! 🤪 Just... |                                                                                                         |
# +----------+---------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email to your team about Sarah's birthday next Friday. Suggest decorating her desk before she arrives (she's usually late), having lunch at her favorite Thai restaurant, and chipping in for a plant as a gift.
# Number of negative samples: 2
# +----------+--------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                            | Explanation (truncated)                                                                                 |
# +==========+==================================================+=========================================================================================================+
# | Sample 1 | Subject: Sarah's birthday next Friday!           | This output is the least stylistically consistent. To be more consistent, add more exclamation point... |
# |          |                                                  |                                                                                                         |
# |          |   Hey team,                                      |                                                                                                         |
# |          |                                                  |                                                                                                         |
# |          |   So, next Friday is Sarah's birthday! 🎉        |                                                                                                         |
# |          |   ...                                            |                                                                                                         |
# +----------+--------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: Sarah's birthday next week!             | The writing is too formal. To better align with the author's style, use more casual language, such a... |
# |          |                                                  |                                                                                                         |
# |          |   Hey team,                                      |                                                                                                         |
# |          |                                                  |                                                                                                         |
# |          |   Just a heads-up that it's Sarah's birthday ... |                                                                                                         |
# +----------+--------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email suggesting a zombie-themed escape room downtown for the next team-building activity, followed by dinner. Mention that everyone can bring a plus-one and you need responses by Tuesday to make the booking for next Friday after work.
# Number of negative samples: 2
# +----------+-----------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                               | Explanation (truncated)                                                                                  |
# +==========+=====================================================+==========================================================================================================+
# | Sample 1 | Subject: Team Building - Escape Room & Dinner? 🧟   | To better align with the author's style, replace "Hey everyone" with "Hey all", add "🔎" after "team-... |
# |          |                                                     |                                                                                                          |
# |          |   Hey everyone,                                     |                                                                                                          |
# |          |                                                     |                                                                                                          |
# |          |   So I was thinking... for ou...                    |                                                                                                          |
# +----------+-----------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: Team building idea - Escape Room + Dinner? | The subject line should include emojis. The phrase "so I was thinking about what to do for our next ...  |
# |          |                                                     |                                                                                                          |
# |          |   Hey everyone,                                     |                                                                                                          |
# |          |                                                     |                                                                                                          |
# |          |   So I was thinking about ...                       |                                                                                                          |
# +----------+-----------------------------------------------------+----------------------------------------------------------------------------------------------------------+
#
# Task: Write an excited email to a friend announcing your trip to their area from May 10-15. Ask to try the brunch place they posted about recently, and request to stay at their place for a few nights since hotels are expensive. Promise to bring their favorite cookies.
# Number of negative samples: 2
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                              | Explanation (truncated)                                                                                 |
# +==========+====================================================+=========================================================================================================+
# | Sample 1 | '''                                                | This candidate is the least consistent. To align with the author's style, it needs more exclamation ... |
# |          |   Subject: Omg guess what?! I'm coming to see you! |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   Hey [Friend's name],                             |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   You are not go...                                |                                                                                                         |
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: Guess what?! I'm coming to visit!         | The subject line should be more enthusiastic with multiple exclamation points. The opening should in... |
# |          |                                                    |                                                                                                         |
# |          |   Hey [Friend's Name],                             |                                                                                                         |
# |          |                                                    |                                                                                                         |
# |          |   OMG, guess what?! I'm plan...                    |                                                                                                         |
# +----------+----------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write an email apologizing for completely forgetting your friend's birthday yesterday because your phone was dead all day. Offer to make it up with dinner at the new Italian restaurant next week.
# Number of negative samples: 2
# +----------+-------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                           | Explanation (truncated)                                                                                 |
# +==========+=================================================+=========================================================================================================+
# | Sample 1 | Subject: OMG I'm so sorry!!                     | The writing is more formal than the original. Replace "I am SO sorry" with "Omg I'm so sorry!!", add... |
# |          |                                                 |                                                                                                         |
# |          |   Hey [Friend's Name],                          |                                                                                                         |
# |          |                                                 |                                                                                                         |
# |          |   I am SO sorry I missed your birthday yest...  |                                                                                                         |
# +----------+-------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: OMG I'm so sorry!                      | The writing is too formal. The emoji usage is inconsistent with the author. The author uses more exc... |
# |          |                                                 |                                                                                                         |
# |          |   Hey [Friend's Name],                          |                                                                                                         |
# |          |                                                 |                                                                                                         |
# |          |   I am SO sorry I missed your birthday yeste... |                                                                                                         |
# +----------+-------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Task: Write a polite complaint email to a local store about finding bacon in your veggie sandwich that you purchased yesterday around 3pm. Mention you'd like to return despite this issue since people say their food is amazing.
# Number of negative samples: 2
# +----------+-------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID       | Candidate (truncated)                                       | Explanation (truncated)                                                                                 |
# +==========+=============================================================+=========================================================================================================+
# | Sample 1 | Subject: veggie sandwich issue                              | This output is the least consistent with the author's style. Adding "Sooo" to the beginning of the e... |
# |          |                                                             |                                                                                                         |
# |          |   Hey there,                                                |                                                                                                         |
# |          |                                                             |                                                                                                         |
# |          |   So, I stopped by yesterday around 3pm and got a ...       |                                                                                                         |
# +----------+-------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Sample 2 | Subject: veggie sandwich issue                              | The output lacks the author's characteristic informality and humor. To align more closely, the subje... |
# |          |                                                             |                                                                                                         |
# |          |   Hey,                                                      |                                                                                                         |
# |          |                                                             |                                                                                                         |
# |          |   So, I got a veggie sandwich from your store yesterday ... |                                                                                                         |
# +----------+-------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
#
# ===== TICL Storage Details =====
#
# Number of samples with negative examples: 12
#
# Sample 1: Write a casual email to Sam discussing yesterday's...
# Number of negative outputs: 2
# +------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                     | Explanation (truncated)                                                                                 |
# +============+========================================================+=========================================================================================================+
# | Negative 1 | Subject: yesterday's meeting...                        | The candidate writing is mostly consistent with the author's style, but the use of excessive emojis ... |
# |            |                                                        |                                                                                                         |
# |            |   Hey Sam,                                             |                                                                                                         |
# |            |                                                        |                                                                                                         |
# |            |   OMG that meeting yesterday was something else, ri... |                                                                                                         |
# +------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | Subject: that meeting yesterday tho 😳                 | The candidate writing is not stylistically consistent with the author's. The author's writing uses m... |
# |            |                                                        |                                                                                                         |
# |            |   Hey Sam,                                             |                                                                                                         |
# |            |                                                        |                                                                                                         |
# |            |   What was up with Alex's idea yesterday?! A ...       |                                                                                                         |
# +------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 2: Write an email to Taylor asking for feedback on a ...
# Number of negative outputs: 2
# +------------+---------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                | Explanation (truncated)                                                                                 |
# +============+===================================================+=========================================================================================================+
# | Negative 1 | ```                                               | The candidate writing is not stylistically consistent with the author's writing. The author uses sho... |
# |            |   Subject: SOS - Need your presentation wizardry! |                                                                                                         |
# |            |                                                   |                                                                                                         |
# |            |   Hey Taylor,                                     |                                                                                                         |
# |            |                                                   |                                                                                                         |
# |            |   Ugh, I'm drowning in thi...                     |                                                                                                         |
# +------------+---------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | Subject: help meeee with this presentation??      | The candidate writing is not fully consistent with the author's style. The author uses shorter parag... |
# |            |                                                   |                                                                                                         |
# |            |   Hey Taylor,                                     |                                                                                                         |
# |            |                                                   |                                                                                                         |
# |            |   So I've been working on this pres...            |                                                                                                         |
# +------------+---------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 3: Write an email apologizing for missing a scheduled...
# Number of negative outputs: 2
# +------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                                | Explanation (truncated)                                                                                 |
# +============+===================================================================+=========================================================================================================+
# | Negative 1 | Subject: Omg so sorry!!                                           | The candidate writing is stylistically inconsistent with the author's writing. The author's writing ... |
# |            |                                                                   |                                                                                                         |
# |            |   Hey!                                                            |                                                                                                         |
# |            |                                                                   |                                                                                                         |
# |            |   I am SO sorry, but I totally missed our call this morning. 🤦‍... |                                                                                                         |
# +------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                                               | The candidate writing is not stylistically consistent with the author's writing. The author uses a m... |
# |            |   Subject: So sorry I missed our call!! 😴                        |                                                                                                         |
# |            |                                                                   |                                                                                                         |
# |            |   Hey!                                                            |                                                                                                         |
# |            |                                                                   |                                                                                                         |
# |            |   OMG I am SO sorry I missed our call thi...                      |                                                                                                         |
# +------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 4: Write an email to your team explaining that you'll...
# Number of negative outputs: 2
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                    | Explanation (truncated)                                                                                 |
# +============+=======================================================+=========================================================================================================+
# | Negative 1 | ```                                                   | The candidate writing is mostly consistent, but some minor adjustments are needed. The author's writ... |
# |            |   Subject: Project Update - Need a lil' more time! 😬 |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Hey team,                                           |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Sooo, I have some not-s...                          |                                                                                                         |
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                                   | The candidate writing is not stylistically consistent with the author's writing. The author uses mor... |
# |            |   Subject: umm about that deadline...                 |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Hey team,                                           |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Sooo, bad news. 😬 Those backend issues...          |                                                                                                         |
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 5: Write an email to your boss requesting vacation da...
# Number of negative outputs: 2
# +------------+----------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                           | Explanation (truncated)                                                                                 |
# +============+==============================================+=========================================================================================================+
# | Negative 1 | ```                                          | The candidate writing lacks the author's informal tone, use of colloquialisms, excessive punctuation... |
# |            |   Subject: vacation request                  |                                                                                                         |
# |            |                                              |                                                                                                         |
# ...
# |            |                                                        |                                                                                                         |
# |            |   Hey team,                                            |                                                                                                         |
# |            |                                                        |                                                                                                         |
# |            |   Sooo, I've noticed everyone's been putting in ext... |                                                                                                         |
# +------------+--------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 8: Write an email to your team about Sarah's birthday...
# Number of negative outputs: 2
# +------------+------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                   | Explanation (truncated)                                                                                 |
# +============+======================================================+=========================================================================================================+
# | Negative 1 | Subject: Sarah's bday next week!                     | The candidate's writing is inconsistent with the author's writing in several ways. (1) The subject l... |
# |            |                                                      |                                                                                                         |
# |            |   Hey team,                                          |                                                                                                         |
# |            |                                                      |                                                                                                         |
# |            |   So Sarah's birthday is next Friday! We should d... |                                                                                                         |
# +------------+------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                                  | The candidate writing lacks the exaggerated informality of the author's writing. (1) The subject lin... |
# |            |   Subject: Sarah's bday next week! 🎉🎉              |                                                                                                         |
# |            |                                                      |                                                                                                         |
# |            |   Hey team,                                          |                                                                                                         |
# |            |                                                      |                                                                                                         |
# |            |   So next Friday is Sarah's birthday! An...          |                                                                                                         |
# +------------+------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 9: Write an email suggesting a zombie-themed escape r...
# Number of negative outputs: 2
# +------------+-------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                              | Explanation (truncated)                                                                                 |
# +============+=================================================+=========================================================================================================+
# | Negative 1 | Subject: team building?? zombies??              | The candidate writing is stylistically inconsistent with the author's writing. The author uses more ... |
# |            |                                                 |                                                                                                         |
# |            |   Hey everyone,                                 |                                                                                                         |
# |            |                                                 |                                                                                                         |
# |            |   Sooo I was thinking for our next team-bui...  |                                                                                                         |
# +------------+-------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                             | The candidate's writing diverges from the author's style in several ways.                               |
# |            |   Subject: team building idea?? 🧟              |                                                                                                         |
# |            |                                                 |   1.  **Tone and Voice:...                                                                              |
# |            |   Hey team,                                     |                                                                                                         |
# |            |                                                 |                                                                                                         |
# |            |   Sooo I was thinking about our next team-bu... |                                                                                                         |
# +------------+-------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 10: Write an excited email to a friend announcing your...
# Number of negative outputs: 2
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                    | Explanation (truncated)                                                                                 |
# +============+=======================================================+=========================================================================================================+
# | Negative 1 | Subject: OMG I'M COMING UR WAYYY!! 🤩                 | The candidate writing is mostly consistent with the author's style, but here are some suggested edit... |
# |            |                                                       |                                                                                                         |
# |            |   Hey [Friend's Name]!                                |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Guess what?! I'm gonna be in you...                 |                                                                                                         |
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                                   | The candidate writing is not stylistically consistent with the author's writing. The author's writin... |
# |            |   Subject: Omg I'm coming to your neck of the woods!! |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Hey [Friend's Name],                                |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Guess what?...                                      |                                                                                                         |
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 11: Write an email apologizing for completely forgetti...
# Number of negative outputs: 2
# +------------+------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                         | Explanation (truncated)                                                                                 |
# +============+============================================================+=========================================================================================================+
# | Negative 1 | ```                                                        | The candidate writing diverges stylistically from the author's writing in several ways. (1) It inclu... |
# |            |   Subject: OMG so sorry about your bday!! 😭               |                                                                                                         |
# |            |                                                            |                                                                                                         |
# |            |   Hey [Friend's Name]!                                     |                                                                                                         |
# |            |                                                            |                                                                                                         |
# |            |   I am SOOOO sorry I mi...                                 |                                                                                                         |
# +------------+------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                                        | The candidate writing is not stylistically consistent with the author's writing. The author uses exc... |
# |            |   Subject: Omg so sorry!!                                  |                                                                                                         |
# |            |                                                            |                                                                                                         |
# |            |   Heyyy!                                                   |                                                                                                         |
# |            |                                                            |                                                                                                         |
# |            |   I'm sooooo sorry, but I totally spaced and forgot you... |                                                                                                         |
# +------------+------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
# Sample 12: Write a polite complaint email to a local store ab...
# Number of negative outputs: 2
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | ID         | Output (truncated)                                    | Explanation (truncated)                                                                                 |
# +============+=======================================================+=========================================================================================================+
# | Negative 1 | ```                                                   | The candidate writing is mostly consistent with the author's style, but some minor adjustments can i... |
# |            |   Subject: veggie sandwich issue :(                   |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Hey there,                                          |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Soooo I got a veggie sandwich from your...          |                                                                                                         |
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# | Negative 2 | ```                                                   | The candidate writing is not stylistically consistent with the author's writing. The author uses a m... |
# |            |   Subject: uhh found bacon in my veggie sandwich?? 🥓 |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   Hey [Store Name],                                   |                                                                                                         |
# |            |                                                       |                                                                                                         |
# |            |   So I got a vegg...                                  |                                                                                                         |
# +------------+-------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
#
#
# ===== Storage Comparison =====
#
# GTICL total negative samples: 24
# TICL total negative samples: 24

# %% [markdown]
# ## Official Evaluation Test
#
# Use the specified prompt template to evaluate which model's generations are more similar to the author's writing style.

# %%
# Define test tasks for the official evaluation
official_eval_tasks = [
    {
        "name": "Project Update",
        "task": "Write an email to update the team on current project status, highlight challenges, and request input on next steps."
    },
    {
        "name": "Office Move",
        "task": "Write an email to inform everyone about our upcoming office move to downtown next month."
    },
    {
        "name": "New Team Member",
        "task": "Write an email to introduce Sarah, our new UX designer who's starting on Monday."
    },
    {
        "name": "Team Outing",
        "task": "Write an email to gather suggestions for our next team outing and schedule a planning meeting."
    },
    {
        "name": "Apology for Birthday",
        "task": "Write an email apologizing for completely forgetting your friend's birthday yesterday because your phone was dead all day. Offer to make it up with dinner at the new Italian restaurant next week.",
    },
    {
        "name": "Vegetarian Sandwich Complaint",
        "task": "Write a polite complaint email to a local store about finding bacon in your veggie sandwich that you purchased yesterday around 3pm. Mention you'd like to return despite this issue since people say their food is amazing.",
    },
    {
        "name": "Vacation Request",
        "task": "Write an email to your boss requesting vacation days from May 15-19 because you're feeling burnt out. Assure them this is before the product launch and you'll have your work completed before leaving.",
    },
    {
        "name": "Feedback Request",
        "task": "Write an email to your mentor asking for feedback on your recent project submission and any areas for improvement."
    },
    {
        "name": "Meeting Follow-Up",
        "task": "Write an email to follow up on the meeting with the client yesterday, summarize key points, and confirm next steps."
    },
    {
        "name": "Project Closure",
        "task": "Write an email to the team announcing the closure of the project, thanking everyone for their hard work, and discussing next steps for future projects."
    },
    {
        "name": "Task Review",
        "task": "Write an email to the project manager suggesting a review of all tasks completed in the last quarter to assess performance and set new goals."
    },
    {
        "name": "Training Session Request",
        "task": "Write an email to HR requesting a training session on effective communication skills for all team members."
    },
    {
        "name": "Weekly Status Update",
        "task": "Write an email to your team providing a status update on ongoing projects and any upcoming deadlines."
    },
    {
        "name": "Dentist Support",
        "task": "Write an email to your colleague offering support as they're nervous about their dentist appointment tomorrow."
    },
    {
        "name": "Pickup Boyfriend's Suit",
        "task": "Write an email to your boyfriend reminding him to pick up his suit from the dry cleaners before the wedding this weekend."
    },
    {
        "name": "Last Minute Gift Reminder",
        "task": "Write an email to your friend reminding them to get a last-minute gift for the wedding."
    },
    {
        "name": "Post-Wedding Thank You",
        "task": "Write an email to guests thanking them for attending the wedding and for their gifts."
    },
    {
        "name": "Birthday Party Invitation",
        "task": "Write an email inviting friends to your birthday party next weekend at the new karaoke place downtown."
    },
    {
        "name": "Dinner Plans",
        "task": "Write an email to your friend confirming dinner plans for tonight at the new Italian restaurant."
    },
    {
        "name": "Movie Night",
        "task": "Write an email to your friends inviting them to a movie night at your place this Saturday."
    },
    {
        "name": "Book Club Meeting",
        "task": "Write an email to book club members reminding them of the meeting next week and suggesting discussion topics."
    },
    {
        "name": "Game Night",
        "task": "Write an email to friends inviting them to a game night at your place this Friday."
    },
    {
        "name": "Coffee Date",
        "task": "Write an email to your crush asking them out for coffee this weekend."
    },
    {
        "name": "Networking Event Invitation",
        "task": "Write an email inviting colleagues to an upcoming networking event next month."
    }
]

print(f"Created {len(official_eval_tasks)} tasks for official evaluation")
# Out:
# Created 24 tasks for official evaluation

# %%
# Generate outputs from GTICL and TICL for each evaluation task
def generate_outputs_for_evaluation(task_info):
    name = task_info["name"]
    task = task_info["task"]
    
    print(f"\n--- Generating outputs for: {name} ---")
    print(f"Task: {task}")
    
    # Generate with GTICL
    gticl_result = gticl.generate_with_alignment(
        task=task
    )
    gticl_output = gticl_result["output"]
    
    # Generate with TICL
    ticl_output = ticl.get_final_output(task)
    
    return {
        "name": name,
        "task": task,
        "gticl_output": gticl_output,
        "ticl_output": ticl_output
    }

# Generate outputs for all evaluation tasks
evaluation_outputs = [generate_outputs_for_evaluation(task) for task in official_eval_tasks]
print(f"Generated outputs for {len(evaluation_outputs)} evaluation tasks")
# Out:
# --- Generating outputs for: Project Update ---
# Task: Write an email to update the team on current project status, highlight challenges, and request input on next steps.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Office Move ---
# Task: Write an email to inform everyone about our upcoming office move to downtown next month.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: New Team Member ---
# Task: Write an email to introduce Sarah, our new UX designer who's starting on Monday.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Team Outing ---
# Task: Write an email to gather suggestions for our next team outing and schedule a planning meeting.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Apology for Birthday ---
# Task: Write an email apologizing for completely forgetting your friend's birthday yesterday because your phone was dead all day. Offer to make it up with dinner at the new Italian restaurant next week.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Vegetarian Sandwich Complaint ---
# Task: Write a polite complaint email to a local store about finding bacon in your veggie sandwich that you purchased yesterday around 3pm. Mention you'd like to return despite this issue since people say their food is amazing.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Vacation Request ---
# Task: Write an email to your boss requesting vacation days from May 15-19 because you're feeling burnt out. Assure them this is before the product launch and you'll have your work completed before leaving.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Feedback Request ---
# Task: Write an email to your mentor asking for feedback on your recent project submission and any areas for improvement.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Meeting Follow-Up ---
# Task: Write an email to follow up on the meeting with the client yesterday, summarize key points, and confirm next steps.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Project Closure ---
# Task: Write an email to the team announcing the closure of the project, thanking everyone for their hard work, and discussing next steps for future projects.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Task Review ---
# Task: Write an email to the project manager suggesting a review of all tasks completed in the last quarter to assess performance and set new goals.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Training Session Request ---
# Task: Write an email to HR requesting a training session on effective communication skills for all team members.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Weekly Status Update ---
# Task: Write an email to your team providing a status update on ongoing projects and any upcoming deadlines.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Dentist Support ---
# Task: Write an email to your colleague offering support as they're nervous about their dentist appointment tomorrow.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Pickup Boyfriend's Suit ---
# Task: Write an email to your boyfriend reminding him to pick up his suit from the dry cleaners before the wedding this weekend.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Last Minute Gift Reminder ---
# Task: Write an email to your friend reminding them to get a last-minute gift for the wedding.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Post-Wedding Thank You ---
# Task: Write an email to guests thanking them for attending the wedding and for their gifts.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Birthday Party Invitation ---
# Task: Write an email inviting friends to your birthday party next weekend at the new karaoke place downtown.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Dinner Plans ---
# Task: Write an email to your friend confirming dinner plans for tonight at the new Italian restaurant.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Movie Night ---
# Task: Write an email to your friends inviting them to a movie night at your place this Saturday.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Book Club Meeting ---
# Task: Write an email to book club members reminding them of the meeting next week and suggesting discussion topics.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Game Night ---
# Task: Write an email to friends inviting them to a game night at your place this Friday.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Coffee Date ---
# Task: Write an email to your crush asking them out for coffee this weekend.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# --- Generating outputs for: Networking Event Invitation ---
# Task: Write an email inviting colleagues to an upcoming networking event next month.
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# Generated outputs for 24 evaluation tasks

# %%
# Function to run the official evaluation using the specified template
def run_official_evaluation(task_output, randomize_order=True):
    # Format author's writing examples from our dataset
    author_examples = "\n\n".join([
        f"EXAMPLE {i+1}: {sample['reference_output']}" 
        for i, sample in enumerate(casual_emails_dataset)
    ])
    
    # Determine which output is A and which is B (randomize to prevent bias)
    if randomize_order and random.random() < 0.5:
        option_a = task_output["ticl_output"]
        option_b = task_output["gticl_output"]
        key_a, key_b = "ticl", "gticl"
    else:
        option_a = task_output["gticl_output"]
        option_b = task_output["ticl_output"]
        key_a, key_b = "gticl", "ticl"
    
    # Format the official evaluation prompt
    evaluation_prompt = f"""You are an impartial evaluator of style similarity. Below are samples of an author's writing and two options.

Author's Writing:
{author_examples}

Option A:
{option_a}

Option B:
{option_b}

Task
Which option is more likely to have been written by the author based on style similarity to the samples given as AUTHOR'S WRITING above? Consider each option's similarity with regards to the (1) length, (2) format, (3) paragraph structure, (4) sentence structure, (5) punctuation, (6) syntax, (7) voice, and (8) diction of the author's writing, but NOT the content it covers. If one option has incoherent/odd text or formatting (e.g., random dashes, repetitive text, random signatures, etc.) that is not present in the author's writing while the other doesn't, it should be considered less similar. {{ "explanation": {{ "length": "<Explanation>", "format": "<Explanation>", "paragraph structure": "<Explanation>", "sentence structure": "<Explanation>", "punctuation": "<Explanation>", "syntax": "<Explanation>", "voice": "<Explanation>", "diction": "<Explanation>", "odd incoherent text/formatting": "<Explanation>" }} "answer": "<The option more similar to the AUTHOR'S WRITING; either A or B>" }} ALWAYS REMAIN IMPARTIAL WHEN EVALUATING OUTPUTS AND PENALIZE ODD INCOHERENT TEXT."""
    
    # Send to LLM for evaluation
    messages = [
        {"role": "system", "content": "You are an impartial evaluator of writing style similarity."},
        {"role": "user", "content": evaluation_prompt}
    ]
    
    response_format = {"type": "json_object"}
    evaluation = llm_provider.generate(messages=messages, response_format=response_format)
    
    # Process response (could be string or dict depending on provider implementation)
    if isinstance(evaluation, str):
        try:
            import json
            evaluation = json.loads(evaluation)
        except json.JSONDecodeError:
            logger.error(f"Failed to parse evaluation response: {evaluation[:100]}...")
            return {
                "error": "Invalid JSON response",
                "raw_response": evaluation
            }
    
    # Map the answer back to actual model names
    if isinstance(evaluation, dict) and "answer" in evaluation:
        winner = evaluation["answer"].strip()
        if winner == "A":
            evaluation["winner"] = key_a
            evaluation["winner_output"] = option_a
            evaluation["loser"] = key_b
            evaluation["loser_output"] = option_b
        elif winner == "B":
            evaluation["winner"] = key_b
            evaluation["winner_output"] = option_b
            evaluation["loser"] = key_a
            evaluation["loser_output"] = option_a
        else:
            evaluation["error"] = f"Unexpected answer: {winner}"
    else:
        evaluation = {
            "error": "Missing 'answer' in response",
            "raw_response": evaluation
        }
    
    return {
        **task_output,  # Include original task info
        "evaluation": evaluation,
        "a_was": key_a,
        "b_was": key_b
    }

# Run the evaluation for each task
official_evaluations = [run_official_evaluation(output) for output in evaluation_outputs]

# Print evaluation results
print("\n=== Official Evaluation Results ===\n")
for result in official_evaluations:
    print(f"Task: {result['name']}")
    if "error" in result.get("evaluation", {}):
        print(f"Error: {result['evaluation']['error']}")
    else:
        winner = result["evaluation"].get("winner", "unknown")
        print(f"Winner: {winner.upper()}")
        if "explanation" in result["evaluation"]:
            print("Key differences:")
            for key, explanation in result["evaluation"]["explanation"].items():
                if len(explanation) > 100:
                    explanation = explanation[:97] + "..."
                print(f"  - {key}: {explanation}")
    print()
# Out:
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# === Official Evaluation Results ===
#
# Task: Project Update
# Winner: GTICL
# Key differences:
#   - length: Both options are similar in length to the provided examples.
#   - format: Both options follow a similar email format with a subject line, greeting, body, and closing.
#   - paragraph structure: Option B's paragraph structure is more similar to the examples, with a slightly longer first para...
#   - sentence structure: Option B has sentence structures that are closer to the author's writing, including more elaborat...
#   - punctuation: Both options use similar punctuation, including emojis and exclamation points, but option B uses ...
#   - syntax: Option B's syntax is more conversational and less formal, aligning better with the provided examp...
#   - voice: Option B has a more casual and collaborative voice, similar to the author's tone.
#   - diction: Option B uses more specific and relatable language ("running into some issues with integrating th...
#   - odd incoherent text/formatting: Option A includes bracketed placeholders like "[insert challenge here]" and "[insert next steps]"...
#
# Task: Office Move
# Winner: TICL
# Key differences:
#   - length: Option B is slightly longer, but both are concise like the author's examples.
#   - format: Both options have a similar format to the provided examples--short email with a subject line and ...
#   - paragraph structure: Both options use short paragraphs, mirroring the author's style.
#   - sentence structure: Option B uses shorter, more exclamatory sentences similar to the author's writing style whereas O...
#   - punctuation: Option B uses more exclamation points and emojis, which is closer to the author's style. Option A...
#   - syntax: Both options have straightforward syntax, similar to the author's writing.
#   - voice: Option B has a more enthusiastic and informal voice, aligning better with the author's frequent u...
#   - diction: Option B uses phrases like 'I know, right??' and 'the works!' which are more in line with the aut...
#   - odd incoherent text/formatting: Neither option contains odd or incoherent text or formatting.
#
# Task: New Team Member
# Winner: TICL
# Key differences:
#   - length: Option B is longer, which aligns better with the average length of the author's writing samples. ...
#   - format: Both options have similar email formats, but Option B includes greetings and closings that are mo...
#   - paragraph structure: Option B uses shorter paragraphs, which is consistent with the author's writing style of breaking...
#   - sentence structure: Option B has more varied sentence structures, including some shorter and more informal sentences,...
#   - punctuation: Option B uses more exclamation points and emojis, and double punctuation, which is a characterist...
#   - syntax: Option B's syntax is more informal and includes phrases like "Guess what?!" and "super cool," whi...
#   - voice: Option B has a more enthusiastic and informal voice, using language that conveys excitement and f...
#   - diction: Option B uses words and phrases like "Heyyy," "super cool," and "gonna love her," which are more ...
#   - odd incoherent text/formatting: Neither option has any incoherent or odd text/formatting.
#
# Task: Team Outing
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the author's writing.
#   - format: Both options adhere to the email format seen in the examples.
#   - paragraph structure: Both options have similar paragraphing to the examples, with short, concise paragraphs.
#   - sentence structure: Option B uses shorter, more informal sentences with colloquialisms, matching the author's style. ...
#   - punctuation: Option B uses more emojis and question marks, which are common in the examples. It also uses doub...
#   - syntax: Option B employs a more casual and conversational syntax, aligning with the author's style. Optio...
#   - voice: Option B demonstrates a more casual and playful voice, characterized by the use of emojis and inf...
#   - diction: Option B uses words and phrases like "lol," "wanna," and "lmk," mirroring the author's informal d...
#   - odd incoherent text/formatting: Option A has a signature at the end, '[Your Name]', which wasn't present in the author's samples.
#
# Task: Apology for Birthday
# Winner: TICL
# Key differences:
#   - length: Option A is longer than Option B, similar to the length of the examples provided.
#   - format: Both options are formatted as emails, similar to the examples. Option A includes more emojis, whi...
#   - paragraph structure: Option A's structure with shorter paragraphs aligns more closely with the provided examples.
#   - sentence structure: Option A utilizes sentence fragments and informal sentence structures, mirroring the examples. Op...
#   - punctuation: Option A uses excessive punctuation (e.g., multiple exclamation points, elongated words with mult...
#   - syntax: Option A has a more conversational and less grammatically strict syntax, similar to the examples....
#   - voice: Option A's voice is more casual, expressive, and apologetic, aligning with the examples. Option B...
#   - diction: Option A uses slang, abbreviations, and informal language (e.g., "OMG", "SOOOO bad", "amaaaazing"...
#   - odd incoherent text/formatting: Option A uses some elongated words and excessive emojis which is consistent with the examples pro...
#
# Task: Vegetarian Sandwich Complaint
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length, aligning with the concise nature of the author's examples.
#   - format: Both options maintain a similar format, starting with a casual greeting and ending with a request...
#   - paragraph structure: Both options have short, direct paragraphs, which is characteristic of the author's style.
#   - sentence structure: Both options use relatively simple sentence structures, as seen in the author's writing.
#   - punctuation: Both options use emojis and exclamation points, which are common in the author's examples. Option...
#   - syntax: The syntax in both options is straightforward and conversational, mirroring the author's style.
#   - voice: Both options adopt a friendly and slightly apologetic tone, consistent with the author's voice.
#   - diction: Both options use casual language. Option B uses the phrase 'kinda a bummer' which aligns with the...
#   - odd incoherent text/formatting: Neither option contains incoherent text or formatting issues.
#
# Task: Vacation Request
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length, though Option B is slightly shorter, aligning with the brevit...
#   - format: Both options follow a similar format, starting with a subject line and including a greeting, body...
#   - paragraph structure: Option B employs shorter paragraphs, mirroring the author's tendency to break up text into smalle...
#   - sentence structure: Option B uses simpler and shorter sentences, which aligns better with the author's style. Option ...
#   - punctuation: Option B uses an emoji, which the author does in their examples. Option B also uses a question ma...
#   - syntax: Option B has a more casual and conversational syntax, using phrases like "Shouldn't be a problem"...
#   - voice: Option B exhibits a more casual and slightly more informal voice, using contractions and a slight...
#   - diction: Option B's word choice is more informal (e.g., "Feeling a little burnt out lately.") and closer t...
#   - odd incoherent text/formatting: Neither option contains odd or incoherent text/formatting.
#
# Task: Feedback Request
# Winner: TICL
# Key differences:
#   - length: Option B is slightly shorter, which aligns better with the brevity seen in the author's examples.
#   - format: Both options follow a similar email format with a subject line and a closing signature. However, ...
#   - paragraph structure: Both options have short paragraphs, but Option B's paragraph structure is closer to the author's ...
#   - sentence structure: Option B uses simpler and shorter sentences, with more informal phrasing. The author's examples a...
#   - punctuation: Option B uses emojis (😭, 😬, 🙏) and multiple exclamation points, which are characteristic of the a...
#   - syntax: Option B's syntax is more informal and conversational, including phrases like "help me pls" and "...
#   - voice: Option B has a more casual and slightly anxious voice, using phrases like "kinda nervous lol." Th...
#   - diction: Option B's diction includes words and phrases like "pls," "pleeeease," and "kinda nervous," which...
#   - odd incoherent text/formatting: Both options are coherent and well-formatted.
#
# Task: Meeting Follow-Up
# Winner: TICL
# Key differences:
#   - length: Option B is closer in length to the examples provided.
#   - format: Option B uses a subject line with an exclamation point, which is a pattern in the examples. It al...
#   - paragraph structure: Option B has shorter paragraphs, similar to the provided examples.
#   - sentence structure: Option B's sentences are less formal and closer to the conversational tone of the examples.
#   - punctuation: Option B uses more informal punctuation (e.g., exclamation points) and emojis, which aligns with ...
#   - syntax: Option B uses more casual sentence structures and includes contractions and informal phrasing, mi...
#   - voice: Option B has a more informal and friendly voice, similar to the examples, whereas Option A is mor...
#   - diction: Option B uses more colloquial language ("Sooo great chatting," "totally get it!") and includes in...
#   - odd incoherent text/formatting: Option A has bracketed placeholders like "[key point 1]" and a signature that is not part of the ...
#
# Task: Project Closure
# Winner: TICL
# Key differences:
#   - length: Option A is shorter, similar to the author's writing, which includes short emails. Option B is sl...
#   - format: Both options follow a standard email format.
#   - paragraph structure: Option A has shorter paragraphs and uses more line breaks, which is consistent with the author's ...
#   - sentence structure: Option A uses shorter, more informal sentences, similar to the author's style. Option B's sentenc...
#   - punctuation: Option A uses more exclamation points, emojis, and casual punctuation (e.g., 'Sooo'), which align...
#   - syntax: Option A's syntax is more casual and conversational, reflecting the author's style. Option B's sy...
#   - voice: Option A has a more informal, enthusiastic, and casual voice, consistent with the author's writin...
#   - diction: Option A uses more colloquial language (e.g., 'Heyyy,' 'donezo,' 'Thx') and emojis, which is char...
#   - odd incoherent text/formatting: Option A uses the author's name in brackets at the end, which is not something the author did in ...
#
# Task: Task Review
# Winner: TICL
# Key differences:
#   - length: Option A is shorter, which aligns with the brevity seen in several of the author's examples. Opti...
#   - format: Both options present a similar email format. However, Option A's sign-off, "Later!", is more in l...
#   - paragraph structure: Option A has shorter paragraphs, mirroring the concise paragraphing in the author's examples. Opt...
#   - sentence structure: Option A uses simpler sentence structures and questions, similar to the author. Option B's senten...
#   - punctuation: Option A includes an ellipsis, which is used multiple times in the author's writing. Option B doe...
#   - syntax: Option A has a more casual syntax, including the conversational phrase "What do you think?" which...
#   - voice: Option A's voice is more casual, friendly, and slightly informal, aligning with the author's tone...
#   - diction: Option A uses words and phrases like "Been thinking..." and "What do you think?", which are more ...
#   - odd incoherent text/formatting: Neither option contains odd or incoherent text or formatting.
#
# Task: Training Session Request
# Winner: TICL
# Key differences:
#   - length: Option B is closer in length to the examples provided.
#   - format: Both options use a standard email format, but Option B's subject line is more stylistically similar.
#   - paragraph structure: Both options have similar paragraph structures, but Option B's is slightly more casual, aligning ...
#   - sentence structure: Option B uses shorter, more informal sentences with interjections like "Sooo" and "lol," which ar...
#   - punctuation: Option B uses more informal punctuation, such as multiple question marks and ellipses, and emojis...
#   - syntax: Option B uses more casual syntax, with words like "sesh" and phrases like "REALLY use," which mir...
#   - voice: Option B has a much more casual and informal voice, similar to the author's writing samples. Opti...
#   - diction: Option B employs more colloquial and informal language, such as "sesh," "lol," and "obvi," which ...
#   - odd incoherent text/formatting: Option B includes the use of emojis that are present in the author's sample writings.
#
# Task: Weekly Status Update
# Winner: TICL
# Key differences:
#   - length: Option B is closer in length to the examples than Option A. Option A is very concise.
#   - format: Both options are formatted as emails with a subject line and greeting. Option B includes emojis, ...
#   - paragraph structure: Option B uses shorter paragraphs, similar to the examples. Option A has denser paragraphs.
#   - sentence structure: Option B uses more informal and conversational sentence structures, including sentence fragments ...
#   - punctuation: Option B uses emojis and more casual punctuation (e.g., ellipses, interrobangs) as seen in the ex...
#   - syntax: Option B's syntax is more relaxed and informal, with colloquialisms and contractions. Option A's ...
#   - voice: Option B has a much more casual and friendly voice, with use of slang and informal language, whic...
#   - diction: Option B uses words and phrases like "chugging along", "a tiny bit behind", "super important", "n...
#   - odd incoherent text/formatting: Option B includes emojis which is consistent with the examples. Neither option has any odd or inc...
#
# Task: Dentist Support
# Winner: TICL
# Key differences:
#   - length: Option B is slightly more concise, aligning with the shorter email examples in the author's writing.
#   - format: Both options follow a similar email format, with a subject line, greeting, body, and closing.
#   - paragraph structure: Option B has a paragraph structure which is more similar to the author's examples, using shorter ...
#   - sentence structure: Option B uses simpler sentence structures and includes rhetorical questions, which align with the...
#   - punctuation: Option B's use of exclamation marks and emojis is more similar to the author's style.
#   - syntax: Both options have correct syntax.
#   - voice: Option B's voice is more casual and enthusiastic, similar to the author's writing. Option A uses ...
#   - diction: Option B's use of phrases like 'not a huge fan haha' and 'you got this' aligns better with the au...
#   - odd incoherent text/formatting: Option A includes '[Colleague's Name]' and '[Your Name]', which are placeholders and do not align...
#
# Task: Pickup Boyfriend's Suit
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the examples.
#   - format: Both options follow the format of a short email/message.
#   - paragraph structure: Both are similar to the examples, using short paragraphs.
#   - sentence structure: Both options use short, informal sentences, similar to the provided examples. Option A has a slig...
#   - punctuation: Option A uses "Heyyy," "lol," and "Love youuu!" similar to the author. Option B uses "😬" and a he...
#   - syntax: Both options use informal syntax.
#   - voice: Both options have a casual, friendly voice. Option A's tone is slightly more playful and exaggera...
#   - diction: Option A uses "Heyyy," "rocking up," and "lol," which are more in line with the author's diction ...
#   - odd incoherent text/formatting: Neither option contains odd or incoherent text or formatting.
#
# Task: Last Minute Gift Reminder
# Winner: TICL
# Key differences:
#   - length: Option B is closer in length to the provided examples, which are generally short and to the point.
#   - format: Both options follow a similar format with a subject line and a brief message. Option B includes '...
#   - paragraph structure: Both options consist of short paragraphs, which is consistent with the provided examples.
#   - sentence structure: Option B employs shorter, more fragmented sentences and includes an exclamation and question mark...
#   - punctuation: Option B uses more exclamation marks and question marks, as well as emojis, which are characteris...
#   - syntax: Option B uses less formal syntax, including sentence fragments and interjections ('Panic time!'),...
#   - voice: Option B's voice is more casual, urgent, and slightly frantic, which is more in line with the aut...
#   - diction: Option B uses words like 'OMG,' 'Panic time!' and 'lol,' which are consistent with the author's u...
#   - odd incoherent text/formatting: Neither option has incoherent text or formatting issues.
#
# Task: Post-Wedding Thank You
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the provided examples, so this is not a major differentiati...
#   - format: Both options use a similar email format, starting with a subject line and a greeting.
#   - paragraph structure: Both options have short paragraphs, similar to the examples.
#   - sentence structure: Both options use relatively simple sentence structures, aligning with the provided examples. Opti...
#   - punctuation: Option B utilizes more exclamation points and emojis, which is more consistent with the author's ...
#   - syntax: The syntax in both options is straightforward and grammatically correct, similar to the examples.
#   - voice: Option B maintains a slightly more casual and enthusiastic voice through the use of exclamation p...
#   - diction: Option B uses words like "HUGE" and "amazing," which are more in line with the author's diction. ...
#   - odd incoherent text/formatting: Neither option has incoherent text or formatting.
#
# Task: Birthday Party Invitation
# Winner: GTICL
# Key differences:
#   - length: Both options are similar in length to the provided examples.
#   - format: Both options include a subject line, a greeting, the body of the message, and a closing. Option A...
#   - paragraph structure: Option A has shorter paragraphs, which aligns better with the author's style of short, often one-...
#   - sentence structure: Option A uses shorter, more exclamatory sentences, similar to the author's writing. Option B's se...
#   - punctuation: Option A uses a greater variety of punctuation, including emojis and multiple exclamation points....
#   - syntax: Both options have similar syntax overall, using informal language.
#   - voice: Option A has a more enthusiastic and expressive voice, using phrases like "It's gonna be epic!" a...
#   - diction: Option A uses words and phrases like "Heyyyy", "luv ya", and multiple emojis, which are consisten...
#   - odd incoherent text/formatting: Option A contains bracketed placeholders for the age and name of the writer. This is odd and brea...
#
# Task: Dinner Plans
# Winner: GTICL
# Key differences:
#   - length: Option A is slightly longer, which aligns with the author's tendency for longer messages.
#   - format: Both options have similar formatting, with a short greeting, body, and closing.
#   - paragraph structure: Both options have similar paragraph structures, with a single paragraph forming the body of the m...
#   - sentence structure: Option A uses shorter, more fragmented sentences (e.g., "I'm starving already, haha. 🤤"), which i...
#   - punctuation: Option A uses more varied punctuation, including emojis and exclamation points, which is characte...
#   - syntax: Option A uses more informal syntax, such as starting a sentence with "Just wanted to...", which a...
#   - voice: Option A has a more enthusiastic and informal voice, using phrases like "I'm starving already, ha...
#   - diction: Option A uses more casual diction, including "gotta", which is consistent with the author's style...
#   - odd incoherent text/formatting: Neither option has incoherent text or formatting.
#
# Task: Movie Night
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the author's writing, which are typically short and to the ...
#   - format: Both options follow a similar email format with a subject line, greeting, body, and sign-off.
#   - paragraph structure: Both options have short paragraphs, similar to the provided examples.
#   - sentence structure: Option B uses more informal sentence structures, like ending a sentence with a preposition and in...
#   - punctuation: Option B uses an ellipsis, an emojie and exclamation points, mirroring the author's frequent use ...
#   - syntax: Option B uses colloquial syntax similar to the examples, such as starting a sentence with "Sooo.....
#   - voice: Option B's voice is more casual and conversational, aligning with the author's informal and frien...
#   - diction: Option B uses more informal language (e.g., "Heyyy guys", "Sooo...") which is characteristic of t...
#   - odd incoherent text/formatting: Both options are coherent and don't have any odd text or formatting.
#
# Task: Book Club Meeting
# Winner: GTICL
# Key differences:
#   - length: Both options are similar in length, but Option B is slightly shorter, which aligns better with so...
#   - format: Both options follow a similar email format with a subject line and a greeting. However, Option B ...
#   - paragraph structure: Option B has shorter paragraphs, which is more consistent with the author's tendency to use short...
#   - sentence structure: Option B uses more informal sentence structures, such as ending a sentence with "lol," which is s...
#   - punctuation: Option B uses an exclamation mark and an emoji, which are common in the author's writing to conve...
#   - syntax: Option B uses more colloquial syntax, such as "See ya then!", which is more aligned with the auth...
#   - voice: Option B has a more casual and playful voice, incorporating elements like "lol" and emojis, which...
#   - diction: Option B uses more informal diction, such as "chat" and "wing it," which is similar to the author...
#   - odd incoherent text/formatting: Neither option contains incoherent text or odd formatting.
#
# Task: Game Night
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the provided examples.
#   - format: Both options follow a similar format of a subject line followed by a short email.
#   - paragraph structure: Both options have short paragraphs, similar to the examples.
#   - sentence structure: Option B has sentence structures more similar to the examples, including the use of questions and...
#   - punctuation: Option B uses more ellipses, question marks, and casual punctuation, which is more in line with t...
#   - syntax: Option B uses more informal syntax, such as 'Wanna' and 'obvi,' which is characteristic of the au...
#   - voice: Option B has a more casual and friendly voice, mirroring the examples. Option A is slightly more ...
#   - diction: Option B employs more colloquial language and filler words ('Soooo,' 'thinking,' 'huh?') that are...
#   - odd incoherent text/formatting: Neither option has any incoherent or odd formatting.
#
# Task: Coffee Date
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the author's writing samples.
#   - format: Both options use a similar informal email format, including a subject line and a casual greeting.
#   - paragraph structure: Both options use short paragraphs, which is consistent with the author's style. Option B may be s...
#   - sentence structure: Both options use relatively simple and informal sentence structures. Option B uses slightly more ...
#   - punctuation: Option B includes emojis and more frequent use of punctuation like ellipses and exclamation marks...
#   - syntax: Both options use correct syntax, but option B's syntax is closer to the author's style of informa...
#   - voice: Option B has a more enthusiastic and casual voice, which aligns better with the author's use of s...
#   - diction: Option B uses words like "wanna" and "lemme," which are common in the author's writing. It also i...
#   - odd incoherent text/formatting: Option B has an emoji in the subject line, and some emojis in the body, which are consistent with...
#
# Task: Networking Event Invitation
# Winner: TICL
# Key differences:
#   - length: Both options are similar in length to the author's writing.
#   - format: Both options follow the format of an email, similar to the author's writing.
#   - paragraph structure: Option A's paragraph structure is more similar to the author's writing, with shorter paragraphs a...
#   - sentence structure: Option A uses a more conversational and less formal sentence structure, as the author does. Optio...
#   - punctuation: Option A uses an emoji and an ellipsis, which are common in the author's writing. Option B uses a...
#   - syntax: Option A's syntax is more informal and conversational, closer to the author's style. It uses "So ...
#   - voice: Option A's voice is more casual and personal, mirroring the author's tone. The use of "nerd face"...
#   - diction: Option A uses words like "thing" and "wanna," which are more casual and align with the author's d...
#   - odd incoherent text/formatting: Both examples are coherent.

# %%
print(official_evaluations)
# Out:
# [{'name': 'Project Update', 'task': 'Write an email to update the team on current project status, highlight challenges, and request input on next steps.', 'gticl_output': "Subject: Project Update - Need your thoughts!\n\nHey Team,\n\nJust wanted to give a quick update on where we're at with the project. Things are moving along, but we've hit a couple snags. 😬\n\nSpecifically, we're running into some issues with integrating the new software. It's proving to be a bigger challenge than we initially thought!\n\nAny brilliant ideas on how to tackle this? Maybe we can hop on a quick call this week to brainstorm next steps? Let me know when you're free!\n\nThanks!\n[Your Name]", 'ticl_output': "```\nSubject: project update + need your brains!\n\nHey team,\n\nQuick update on where we're at with the project. We're mostly on track, but hitting a few snags. 😬\n\nBiggest challenge rn is [insert challenge here]. Anyone have thoughts on how to tackle this?\n\nAlso, need input on next steps for [insert next steps]. What are we thinking?\n\nLet's chat soon!\n[Your Name]\n```", 'evaluation': {'explanation': {'length': 'Both options are similar in length to the provided examples.', 'format': 'Both options follow a similar email format with a subject line, greeting, body, and closing.', 'paragraph structure': "Option B's paragraph structure is more similar to the examples, with a slightly longer first paragraph and more detailed explanations.", 'sentence structure': "Option B has sentence structures that are closer to the author's writing, including more elaboration and conversational phrasing.", 'punctuation': "Both options use similar punctuation, including emojis and exclamation points, but option B uses these elements a bit more like the author's examples.", 'syntax': "Option B's syntax is more conversational and less formal, aligning better with the provided examples.", 'voice': "Option B has a more casual and collaborative voice, similar to the author's tone.", 'diction': 'Option B uses more specific and relatable language ("running into some issues with integrating the new software") and includes phrases like "brilliant ideas" and "hop on a quick call," which are more in line with the author\'s diction.', 'odd incoherent text/formatting': 'Option A includes bracketed placeholders like "[insert challenge here]" and "[insert next steps]", which is not present in the author\'s original writing and appears odd. Option B does not have this issue.'}, 'answer': 'B', 'winner': 'gticl', 'winner_output': "Subject: Project Update - Need your thoughts!\n\nHey Team,\n\nJust wanted to give a quick update on where we're at with the project. Things are moving along, but we've hit a couple snags. 😬\n\nSpecifically, we're running into some issues with integrating the new software. It's proving to be a bigger challenge than we initially thought!\n\nAny brilliant ideas on how to tackle this? Maybe we can hop on a quick call this week to brainstorm next steps? Let me know when you're free!\n\nThanks!\n[Your Name]", 'loser': 'ticl', 'loser_output': "```\nSubject: project update + need your brains!\n\nHey team,\n\nQuick update on where we're at with the project. We're mostly on track, but hitting a few snags. 😬\n\nBiggest challenge rn is [insert challenge here]. Anyone have thoughts on how to tackle this?\n\nAlso, need input on next steps for [insert next steps]. What are we thinking?\n\nLet's chat soon!\n[Your Name]\n```"}, 'a_was': 'ticl', 'b_was': 'gticl'}, {'name': 'Office Move', 'task': 'Write an email to inform everyone about our upcoming office move to downtown next month.', 'gticl_output': "Subject: office move next month!\n\nHey everyone,\n\nJust wanted to let you know that we're officially moving downtown next month! 🎉\n\nMore details to come soon, but mark your calendars. It's gonna be a bit hectic, but hopefully worth it in the end lol.\n\nLet me know if you have any questions!\n[Your Name]", 'ticl_output': "```\nSubject: We're moving!! 🏢\n\nHey all ...

# %%
# Summarize the official evaluation results
def summarize_evaluations(evaluations):
    total = len(evaluations)
    valid_evals = [e for e in evaluations if "error" not in e.get("evaluation", {})]
    valid_count = len(valid_evals)
    
    if valid_count == 0:
        return {"error": "No valid evaluations found"}
    
    # Count wins by framework
    gticl_wins = sum(1 for e in valid_evals if e["evaluation"].get("winner") == "gticl")
    ticl_wins = sum(1 for e in valid_evals if e["evaluation"].get("winner") == "ticl")
    
    # Calculate percentages
    gticl_win_pct = (gticl_wins / valid_count) * 100 if valid_count > 0 else 0
    ticl_win_pct = (ticl_wins / valid_count) * 100 if valid_count > 0 else 0
    
    # Calculate by category (assuming 10 tasks per category)
    categories = {
        "Work-related": valid_evals[:10],
        "Social/team": valid_evals[10:20] if len(valid_evals) > 10 else [],
        "Personal/external": valid_evals[20:30] if len(valid_evals) > 20 else []
    }
    
    category_results = {}
    
    for category_name, category_evals in categories.items():
        if not category_evals:
            continue
            
        cat_total = len(category_evals)
        cat_gticl_wins = sum(1 for e in category_evals if e["evaluation"].get("winner") == "gticl")
        cat_ticl_wins = sum(1 for e in category_evals if e["evaluation"].get("winner") == "ticl")
        
        cat_gticl_pct = (cat_gticl_wins / cat_total) * 100 if cat_total > 0 else 0
        cat_ticl_pct = (cat_ticl_wins / cat_total) * 100 if cat_total > 0 else 0
        
        category_results[category_name] = {
            "total": cat_total,
            "gticl_wins": cat_gticl_wins,
            "ticl_wins": cat_ticl_wins,
            "gticl_win_percentage": cat_gticl_pct,
            "ticl_win_percentage": cat_ticl_pct
        }
    
    # Create detailed report
    summary = {
        "total_tasks": total,
        "valid_evaluations": valid_count,
        "gticl_wins": gticl_wins,
        "ticl_wins": ticl_wins,
        "gticl_win_percentage": gticl_win_pct,
        "ticl_win_percentage": ticl_win_pct,
        "categories": category_results
    }
    
    return summary

# Generate and display summary
eval_summary = summarize_evaluations(official_evaluations)

print("\n===== Official Evaluation Summary =====\n")
print(f"Total tasks evaluated: {eval_summary['total_tasks']}")
print(f"Valid evaluations: {eval_summary['valid_evaluations']}")
print(f"GTICL wins: {eval_summary['gticl_wins']} ({eval_summary['gticl_win_percentage']:.1f}%)")
print(f"TICL wins: {eval_summary['ticl_wins']} ({eval_summary['ticl_win_percentage']:.1f}%)")

# Print category results
print("\nResults by Category:")
for category_name, results in eval_summary.get('categories', {}).items():
    print(f"\n{category_name}:")
    print(f"  Tasks: {results['total']}")
    print(f"  GTICL wins: {results['gticl_wins']} ({results['gticl_win_percentage']:.1f}%)")
    print(f"  TICL wins: {results['ticl_wins']} ({results['ticl_win_percentage']:.1f}%)")

# Determine overall winner
if eval_summary.get('gticl_win_percentage', 0) > eval_summary.get('ticl_win_percentage', 0):
    print("\nOverall winner: GTICL")
elif eval_summary.get('ticl_win_percentage', 0) > eval_summary.get('gticl_win_percentage', 0):
    print("\nOverall winner: TICL")
else:
    print("\nResult: Tie")

# %%
# Function to print detailed results with formatted outputs
def print_detailed_comparison(eval_result):
    print(f"\n===== Detailed Comparison: {eval_result['name']} =====\n")
    print(f"Task: {eval_result['task']}")
    print(f"Input: {eval_result['input']}")
    
    # Print the winner's output first
    if "evaluation" in eval_result and "winner" in eval_result["evaluation"]:
        winner = eval_result["evaluation"]["winner"]
        loser = eval_result["evaluation"]["loser"]
        
        print(f"\n🏆 {winner.upper()} Output (WINNER):")
        print(f"{eval_result[winner + '_output']}")
        
        print(f"\n{loser.upper()} Output:")
        print(f"{eval_result[loser + '_output']}")
        
        # Print evaluation details
        print("\nEvaluation Details:")
        for key, explanation in eval_result["evaluation"].get("explanation", {}).items():
            print(f"  • {key.title()}: {explanation}")
    else:
        # If no evaluation available, just print both outputs
        print("\nGTICL Output:")
        print(eval_result["gticl_output"])
        print("\nTICL Output:")
        print(eval_result["ticl_output"])

# Print detailed comparison for each task
for eval_result in official_evaluations:
    print_detailed_comparison(eval_result)

# %%
# Generate a comprehensive final report
def generate_final_report(summary, significance, examples_count=12, eval_tasks_count=30):
    """Generate a final report on the GTICL vs TICL comparison."""
    
    report = f"""# GTICL vs TICL Comparison Final Report

## Experiment Setup
- Training examples: {examples_count} casual email writing samples with consistent author style
- Evaluation tasks: {eval_tasks_count} email writing tasks across three categories
- Categories: Work-related, Social/team, and Personal/external communications
- LLM Model: {os.getenv('LLM_MODEL_ID')} via OpenRouter
- GTICL Configuration: k_candidates={gticl_config.k_candidates}, iterations={gticl_config.iterations}, examples_per_prompt={gticl_config.examples_per_prompt}
- TICL Configuration: iterations={ticl.iterations}, examples_per_prompt={ticl.examples_per_prompt}

## Overall Results
- Valid evaluations: {summary['valid_evaluations']} out of {summary['total_tasks']}
- GTICL wins: {summary['gticl_wins']} ({summary['gticl_win_percentage']:.1f}%)
- TICL wins: {summary['ticl_wins']} ({summary['ticl_win_percentage']:.1f}%)

## Results by Category
"""
    
    for category_name, results in summary.get('categories', {}).items():
        report += f"### {category_name}\n"
        report += f"- Tasks: {results['total']}\n"
        report += f"- GTICL wins: {results['gticl_wins']} ({results['gticl_win_percentage']:.1f}%)\n"
        report += f"- TICL wins: {results['ticl_wins']} ({results['ticl_win_percentage']:.1f}%)\n\n"
    
    report += "## Statistical Significance\n"
    
    if "error" not in significance:
        report += f"- Sample size: {significance['sample_size']} evaluations\n"
        report += f"- GTICL win rate: {significance['gticl_win_rate']:.2f}\n"
        report += f"- 95% Confidence interval: ({significance['confidence_interval_95'][0]:.2f}, {significance['confidence_interval_95'][1]:.2f})\n"
        report += f"- P-value: {significance['p_value']:.4f}\n\n"
        
        if significance["significant_05"]:
            if significance["significant_01"]:
                report += "Result is statistically significant at the 1% level.\n"
            else:
                report += "Result is statistically significant at the 5% level.\n"
        else:
            report += "Result is not statistically significant at the 5% level.\n"
    else:
        report += significance["error"] + "\n"
    
    report += "\n## Conclusion\n"
    
    # Determine the winner for the conclusion
    if summary['gticl_win_percentage'] > summary['ticl_win_percentage']:
        if significance.get("significant_05", False):
            report += "GTICL significantly outperforms TICL in matching the author's casual email writing style. "
        else:
            report += "GTICL appears to outperform TICL in matching the author's casual email writing style, but the difference is not statistically significant. "
    elif summary['ticl_win_percentage'] > summary['gticl_win_percentage']:
        if significance.get("significant_05", False):
            report += "TICL significantly outperforms GTICL in matching the author's casual email writing style. "
        else:
            report += "TICL appears to outperform GTICL in matching the author's casual email writing style, but the difference is not statistically significant. "
    else:
        report += "Both frameworks perform equally in matching the author's casual email writing style. "
    
    # Add category-specific insights
    category_insights = []
    for category_name, results in summary.get('categories', {}).items():
        if results['gticl_win_percentage'] > results['ticl_win_percentage'] + 10:
            category_insights.append(f"GTICL performed notably better for {category_name.lower()} emails")
        elif results['ticl_win_percentage'] > results['gticl_win_percentage'] + 10:
            category_insights.append(f"TICL performed notably better for {category_name.lower()} emails")
    
    if category_insights:
        report += "Category-specific insights: " + "; ".join(category_insights) + ".\n\n"
    
    # Add final recommendation
    report += "\n## Recommendation\n"
    
    if "error" not in significance and significance.get("significant_05", False):
        if summary['gticl_win_percentage'] > summary['ticl_win_percentage']:
            report += "Based on statistically significant results, GTICL is recommended for style matching tasks in casual email writing."
        else:
            report += "Based on statistically significant results, TICL is recommended for style matching tasks in casual email writing."
    else:
        report += "Further testing with a larger sample size is recommended to establish a statistically significant difference between the frameworks."
    
    return report

# Generate and display final report
final_report = generate_final_report(eval_summary, significance_results)
print(final_report)

# Save the report to a file
report_path = "gticl_vs_ticl_comparison_report.md"
with open(report_path, "w") as f:
    f.write(final_report)

print(f"Final report saved to '{report_path}'")
